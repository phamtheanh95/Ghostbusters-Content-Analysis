# %%
# importing all necessary packages
import numpy as np
import pandas as pd
import re
import itertools
import math
import ast

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from nltk.corpus import stopwords

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.decomposition import LatentDirichletAllocation

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from collections import Counter

from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics.pairwise import euclidean_distances

from IPython.display import Image
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# # My Workflow

# %%
Image(filename='workflow.png', width = 1500, height = 400)

# %% [markdown]
# # 1. Imports

# %%
# loading datasets
comments = pd.read_csv('video_comments.csv')
descriptions = pd.read_csv('video_descriptions.csv', engine='python')

# %% [markdown]
# # 2. Proprocessing and Normalizing Functions

# %%
# functions to preprocess the text
CONTRACTION_MAP = {"ain't": "is not","aren't": "are not","can't": "cannot","can't've": "cannot have","'cause": "because","could've": "could have","couldn't": "could not","couldn't've": "could not have","didn't": "did not","doesn't": "does not","don't": "do not","hadn't": "had not","hadn't've": "had not have","hasn't": "has not","haven't": "have not","he'd": "he would","he'd've": "he would have","he'll": "he will","he'll've": "he he will have","he's": "he is","how'd": "how did","how'd'y": "how do you","how'll": "how will","how's": "how is","I'd": "I would","I'd've": "I would have","I'll": "I will","I'll've": "I will have","I'm": "I am","I've": "I have","i'd": "i would","i'd've": "i would have","i'll": "i will","i'll've": "i will have","i'm": "i am","i've": "i have","isn't": "is not","it'd": "it would","it'd've": "it would have","it'll": "it will","it'll've": "it will have","it's": "it is","let's": "let us","ma'am": "madam","mayn't": "may not","might've": "might have","mightn't": "might not","mightn't've": "might not have","must've": "must have","mustn't": "must not","mustn't've": "must not have","needn't": "need not","needn't've": "need not have","o'clock": "of the clock","oughtn't": "ought not","oughtn't've": "ought not have","shan't": "shall not","sha'n't": "shall not","shan't've": "shall not have","she'd": "she would","she'd've": "she would have","she'll": "she will","she'll've": "she will have","she's": "she is","should've": "should have","shouldn't": "should not","shouldn't've": "should not have","so've": "so have","so's": "so as","that'd": "that would","that'd've": "that would have","that's": "that is","there'd": "there would","there'd've": "there would have","there's": "there is","they'd": "they would","they'd've": "they would have","they'll": "they will","they'll've": "they will have","they're": "they are","they've": "they have","to've": "to have","wasn't": "was not","we'd": "we would","we'd've": "we would have","we'll": "we will","we'll've": "we will have","we're": "we are","we've": "we have","weren't": "were not","what'll": "what will","what'll've": "what will have","what're": "what are","what's": "what is","what've": "what have","when's": "when is","when've": "when have","where'd": "where did","where's": "where is","where've": "where have","who'll": "who will","who'll've": "who will have","who's": "who is","who've": "who have","why's": "why is","why've": "why have","will've": "will have","won't": "will not","won't've": "will not have","would've": "would have","wouldn't": "would not","wouldn't've": "would not have","y'all": "you all","y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would","you'd've": "you would have","you'll": "you will","you'll've": "you will have","you're": "you are","you've": "you have"}

# expanding the contractions
def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower()) 
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
    expanded_text = contractions_pattern.sub(expand_match, text) 
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

# normalizing text (removing links), special characters, and expanding contractions
def normalize(s):
    s = str(s)
    stripped = re.sub('http://\S+|https://\S+', '', s)
    stripped = re.sub(r'[^a-zA-z0-9\s]' , '', stripped)
    stripped = re.sub('\n','',stripped)
    stripped = re.sub('_','',stripped)
    stripped = re.sub('-','',stripped)
    stripped = stripped.lower()
    stripped = stripped.strip("[]")
    stripped = expand_contractions(stripped)
    return stripped

# creating a set of stop words. more stop words are updated for these datasets
stop_words = set(stopwords.words('english'))
extra_words = ["[","]",'copyright','1','2','3','4','5','us','tumblr','patreon','twitter', 'facebook', 'creepypasta', 'instagram', 'like', 'video','subscribe', 'please', 'channel', 'comment', 'forget',  'check',   'thanks',  'guys',    'enjoy',   'share',   'follow', 'plea', 'watching', "'", "'d", "'ll", 'abov', 'ani', 'becaus', 'befor', 'could', 'doe', 'dure', 'ha', 'hi', 'might', 'must', "n't", 'need', 'onc', 'onli', 'ourselv', 'r', 'sha', 'themselv', 'thi', 'v', 'veri', 'wa', 'whi', 'wo', 'would', 'yourselv','becau', 'guy', 'pleas', 'subscrib', 'thank', 'watch']
for w in extra_words:
    stop_words.add(w)

# preprocessing text: normalizing and then tokenizing
def preprocess(text):
    preprocessed = normalize(text)
    tokens = word_tokenize(preprocessed)
    filtered_tokens = [token for token in tokens if token not in stop_words_2]
    return filtered_tokens

# %% [markdown]
# # 3. Finding Ghostbusters Related Videos

# %% [markdown]
# ## 3.1 Video/Descriptions Dataset Cleaning

# %%
# getting info of description df
descriptions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38521 entries, 0 to 38520
# Data columns (total 9 columns):
# Video ID           38521 non-null object
# Video Title        38521 non-null object
# tag                36191 non-null object
# Description        37931 non-null object
# Video Post Date    38521 non-null object
# Video Owner ID     38521 non-null object
# No. of Comments    36338 non-null float64
# No. of Likes       36207 non-null float64
# No. of Dislikes    36207 non-null float64
# dtypes: float64(3), object(6)
# memory usage: 2.6+ MB

# %%
# columns and ...
descriptions.columns
# Out:
# Index(['Video ID', 'Video Title', 'tag', 'Description', 'Video Post Date',
#        'Video Owner ID', 'No. of Comments', 'No. of Likes', 'No. of Dislikes'],
#       dtype='object')

# %%
# changing column names for descriptions dataset
descriptions = descriptions.rename({'Video ID': 'vid_id', 
                                    'Video Title': 'vid_title',
                                    'Description':'vid_des',
                                    'Video Post Date': 'post_date',
                                    'Video Owner ID': 'owner_id',
                                    'No. of Comments': 'com_num',
                                    'No. of Likes': 'like_num',
                                    'No. of Dislikes': 'dis_num'}, axis=1)

# %% [markdown]
# ## 3.2 Creating/Preprocessing Text Columns for Video Dataset

# %%
# creating two text columns: 1 for the text data of all three texual columns (tag, title, description) and 1 for only title and description.
descriptions['post_date'] = pd.to_datetime(descriptions['post_date'])
descriptions['tag'] = descriptions['tag'].apply(lambda x: str(x)[1:-1]).replace('a','')
descriptions['text'] = descriptions['tag'] + " " + descriptions['vid_title'] + " " + descriptions['vid_des']

# the reason behind this division is that very often tags are created to optimize the platform (here is youtube) searching results
# thus having nothing to do with the content of the video itself
descriptions['title_des_text'] = descriptions['vid_title'] + " " + descriptions['vid_des']

# %%
# precprocessing entire text data of each row
# %%time
descriptions['text_tokens'] = descriptions['text'].apply(lambda x: preprocess(x))
# Out:
# CPU times: user 1min 8s, sys: 182 ms, total: 1min 8s
# Wall time: 1min 8s

# %%
# precprocessing only title and description text data of each row
# %%time
descriptions['title_des_tokens'] = descriptions['title_des_text'].apply(lambda x: preprocess(x))
# Out:
# CPU times: user 48.5 s, sys: 94.9 ms, total: 48.6 s
# Wall time: 48.6 s

# %%
# now taking a look at the dataset
descriptions.head()
# Out:
#                                  vid_id  \
# 0  594a62c8-f3e4-4f0e-9279-7b6a011a8c69
# 1  58d540d0-57c5-4fae-b4d3-6b93cfda20e2
# 2  59be698a-50a9-460c-933b-c67ab61396a6
# 3  5970bcec-af13-48b4-a7db-b31b9dbf8878
# 4  58e6981e-cb14-4ff1-ac02-86e7f2781105
#
#                                            vid_title  \
# 0                       Nightmare Fredbear simulator
# 1  Geek Week - Can we build a lift into space? - ...
# 2  Drag Racing With DIY Drone Engineer Zoe Stumbaugh
# 3  Ghostbusters: The Video Game Pt.9 || PS3 || Wh...
# 4                                    Conscious Dream
#
#                                                  tag  \
# 0  'fnaf 4', 'Horror (Film Genre)', 'fnaf', 'Horr...
# 1  'Space', 'Mars', 'Answers', 'Universe', 'Top G...
# 2  'technology', 'erik franco', 'science', 'VR', ...
# 3
# 4  'Space Music', 'Electronica (Musical Genre)', ...
#
#                                              vid_des  \
# 0  The Game - http://gamejolt.com/games/nightmare...
# 1  In this week of the geek, Mr James May finds o...
# 2  The ubiquity of drones in the modern world has...
# 3  This is my playthrough of Ghostbusters: The Vi...
# 4  An original Ambient Sci-fi style creation of m...
#
#                   post_date                              owner_id  com_num  \
# 0 2015-11-21 14:04:34+00:00  593006fb-d552-4625-b6af-b4f302a05af8      2.0
# 1 2013-08-06 06:29:29+00:00  58d3d492-3660-40bc-b7c2-d6635baeda31    589.0
# 2 2017-09-14 15:30:43+00:00  59bbf417-88dd-4968-96e8-ce55476bb55a    137.0
# 3 2013-11-05 11:40:15+00:00  59605afb-d248-4281-a439-180a4ec654d6      NaN
# 4 2014-10-17 07:05:07+00:00  58d453fa-c692-4729-a7d0-165b8acf9eef      NaN
#
#    like_num  dis_num                                               text  \
# 0      16.0      1.0  'fnaf 4', 'Horror (Film Genre)', 'fnaf', 'Horr...
# 1    4194.0     37.0  'Space', 'Mars', 'Answers', 'Universe', 'Top G...
# 2     535.0    127.0  'technology', 'erik franco', 'science', 'VR', ...
# 3       NaN      NaN   Ghostbusters: The Video Game Pt.9 || PS3 || W...
# 4       0.0      0.0  'Space Music', 'Electronica (Musical Genre)', ...
#
#                                       title_des_text  \
# 0  Nightmare Fredbear simulator The Game - http:/...
# 1  Geek Week - Can we build a lift into space? - ...
# 2  Drag Racing With DIY Drone Engineer Zoe Stumba...
# 3  Ghostbusters: The Video Game Pt.9 || PS3 || Wh...
# 4  Conscious Dream An original Ambient Sci-fi sty...
#
#                                          text_tokens  \
# 0  [fnaf, horror, film, genre, fnaf, horror, come...
# 1  [space, mars, answers, universe, top, gear, sc...
# 2  [technology, erik, franco, science, vr, vice, ...
# 3  [ghostbusters, game, pt9, ps3, dont, go, away,...
# 4  [space, music, electronica, musical, genre, te...
#
#                                     title_des_tokens
# 0             [nightmare, fredbear, simulator, game]
# 1  [geek, week, build, lift, space, james, mays, ...
# 2  [drag, racing, diy, drone, engineer, zoe, stum...
# 3  [ghostbusters, game, pt9, ps3, dont, go, away,...
# 4  [conscious, dream, original, ambient, scifi, s...

# %% [markdown]
# ## 3.3 Preparing for the Matcher Patterns

# %%
# creating a corpus for both concatenated text columns. First, all text
text_tokens = list(descriptions['text_tokens'])
text_corpus = set(itertools.chain(*text_tokens))

# %%
# using matcher to match ghostbuster to the all text text corpus
process.extract('ghostbuster', text_corpus, limit = 90)
# Out:
# [('ghostbuster', 100),
#  ('ghostbuster3', 96),
#  ('ghostbustera', 96),
#  ('ghostsbuster', 96),
#  ('3ghostbuster', 96),
#  ('ghostbuster5', 96),
#  ('ghostbustier', 96),
#  ('ghostbusters', 96),
#  ('hostbuster', 95),
#  ('ghosbuster', 95),
#  ('ghostbster', 95),
#  ('ghostbuste', 95),
#  ('ghostbustuers', 92),
#  ('ghoastbusters', 92),
#  ('xghostbusters', 92),
#  ('ghosttbusters', 92),
#  ('ghostbursters', 92),
#  ('ghostbusters3', 92),
#  ('ghostbusters4', 92),
#  ('7ghostbusters', 92),
#  ('4ghostbusters', 92),
#  ('ghostbusters6', 92),
#  ('cghostbusters', 92),
#  ('ghostsbusters', 92),
#  ('ghostbustersi', 92),
#  ('ghoistbusters', 92),
#  ('5ghostbusters', 92),
#  ('ghostbusters5', 92),
#  ('ghostbusters2', 92),
#  ('ghostbusterss', 92),
#  ('ghostbuasters', 92),
#  ('ghostubusters', 92),
#  ('2ghostbusters', 92),
#  ('ghostbusteres', 92),
#  ('\\nghostbusters', 92),
#  ('ghostbustersc', 92),
#  ('ghostbusters9', 92),
#  ('ghostebusters', 92),
#  ('ghostbbusters', 92),
#  ('ghostbustsers', 92),
#  ('8ghostbusters', 92),
#  ('ghostbusers', 91),
#  ('ghosbusters', 91),
#  ('ghostbuters', 91),
#  ('ghostusters', 91),
#  ('ghostbustrs', 91),
#  ('ghostbustes', 91),
#  ('ghostbsters', 91),
#  ('ghstbusters', 91),
#  ('gostbusters', 91),
#  ('hostbusters', 91),
#  ('mezcoghostbusters', 90),
#  ('ownersghostbusters', 90),
#  ('ghostbustersanother', 90),
#  ('minecraftghostbustersmod', 90),
#  ('ghostbustersspice', 90),
#  ('animashghostbusters', 90),
#  ('guyghostbusterscourage', 90),
#  ('sivanghostbusters', 90),
#  ('paintingghostbusters', 90),
#  ('quotghostbustersquot', 90),
#  ('cutcaddyshackghostbusters', 90),
#  ('wwwarizonaghostbusterscomthis', 90),
#  ('spectrumghostbusters', 90),
#  ('ghostbustersafterlifetrailerbreakdown', 90),
#  ('congraturationsghostbusters', 90),
#  ('ghostbustersprodukte', 90),
#  ('makeghostbustersgreatagain', 90),
#  ('ghost', 90),
#  ('\\nghostbusters2020\\ngb2020\\n2020\\necto\\necto1\\nmovie', 90),
#  ('chrisknighttherealreview3000comghostbustersafterlife', 90),
#  ('buster', 90),
#  ('ghostbustersafterlife', 90),
#  ('groupghostbusters', 90),
#  ('jaffeghostbusters', 90),
#  ('21717ghostbusters', 90),
#  ('baseballghostbusters', 90),
#  ('ghostbustersreview', 90),
#  ('ghostbusterssnowball', 90),
#  ('ghostbustersafterlifetrailerreaction', 90),
#  ('randolphghostbusters', 90),
#  ('opinionghostbusters', 90),
#  ('hereghostbustersthe', 90),
#  ('titlesghostbusters', 90),
#  ('mcdonaldghostbusters', 90),
#  ('ghostbusterstrailerreaction', 90),
#  ('ghostbusterstotal', 90),
#  ('streetghostbusters2016', 90),
#  ('ghostbustersheres', 90),
#  ('ghostbustersfriend', 90)]

# %%
# and movie
process.extract('movie', text_corpus, limit=25)
# Out:
# [('movie', 100),
#  ('movie5', 91),
#  ('moviea', 91),
#  ('1movie', 91),
#  ('4movie', 91),
#  ('movies', 91),
#  ('moviei', 91),
#  ('moview', 91),
#  ('movie2', 91),
#  ('movie3', 91),
#  ('imovie', 91),
#  ('bmovie', 91),
#  ('movie6', 91),
#  ('moviequality', 90),
#  ('moviestarwars', 90),
#  ('movietelevision', 90),
#  ('supercutmovies', 90),
#  ('movievideo', 90),
#  ('gorthemoviegodhotmailcom', 90),
#  ('moviealso', 90),
#  ('laurenlovesmovies', 90),
#  ('maxmoviereviews', 90),
#  ('ostmovie', 90),
#  ('wwwfandangocomcmpmovieclipsyoutubedesc', 90),
#  ('actionmovies', 90)]

# %%
# and film
process.extract('films', text_corpus, limit=25)
# Out:
# [('films', 100),
#  ('gfilms', 91),
#  ('filmsa', 91),
#  ('filmsi', 91),
#  ('fillms', 91),
#  ('filmes', 91),
#  ('bfilms', 91),
#  ('fi', 90),
#  ('complaintsfilms27', 90),
#  ('wwwdavidscottfilmscomjohns', 90),
#  ('preachersfilms', 90),
#  ('blogfilmspractical', 90),
#  ('filmsvfx', 90),
#  ('filmsripd', 90),
#  ('showsfilms', 90),
#  ('filmstrickster', 90),
#  ('chrisconnorfilmsgmailcommusic', 90),
#  ('filmszack', 90),
#  ('minecraftfilmsdont', 90),
#  ('geeksignercomfilms', 90),
#  ('beyondfilms', 90),
#  ('filmscheck', 90),
#  ('overfilms', 90),
#  ('bigjackfilms', 90),
#  ('filmsdirected', 90)]

# %%
process.extract('film', text_corpus, limit=25)
# Out:
# [('film\\\\', 100),
#  ('film', 100),
#  ('whomfilmed', 90),
#  ('filmlertrolls', 90),
#  ('trainfilmed', 90),
#  ('fi', 90),
#  ('complaintsfilms27', 90),
#  ('fantasyabenteuerfilm', 90),
#  ('wwwdavidscottfilmscomjohns', 90),
#  ('actorfilmmaker', 90),
#  ('gfilms', 90),
#  ('preachersfilms', 90),
#  ('syfyfilm', 90),
#  ('filmthis', 90),
#  ('diefilmfabrik', 90),
#  ('autobotsfilm', 90),
#  ('blogfilmspractical', 90),
#  ('everfilmed', 90),
#  ('camerafilmed', 90),
#  ('wwwawitfilmchallengecom', 90),
#  ('wisdomfilm', 90),
#  ('filmmakera', 90),
#  ('fanfilm', 90),
#  ('filmdocs', 90),
#  ('offilm', 90)]

# %%
# now build the corpus for the text data of only title and description
title_des_tokens = list(descriptions['title_des_tokens'])
title_des_corpus = set(itertools.chain(*title_des_tokens))

# %%
# matching ghostbuster again
process.extract('ghostbuster', title_des_corpus, limit = 50)
# Out:
# [('ghostbuster', 100),
#  ('ghostbuster3', 96),
#  ('ghostbustera', 96),
#  ('ghostsbuster', 96),
#  ('3ghostbuster', 96),
#  ('ghostbuster5', 96),
#  ('ghostbusters', 96),
#  ('ghosbuster', 95),
#  ('ghostbster', 95),
#  ('ghostbuste', 95),
#  ('xghostbusters', 92),
#  ('ghosttbusters', 92),
#  ('ghostbusters3', 92),
#  ('ghostbusters4', 92),
#  ('7ghostbusters', 92),
#  ('4ghostbusters', 92),
#  ('ghostbusters6', 92),
#  ('cghostbusters', 92),
#  ('ghostsbusters', 92),
#  ('ghostbustersi', 92),
#  ('5ghostbusters', 92),
#  ('ghostbusters5', 92),
#  ('ghostbusters2', 92),
#  ('ghostbusterss', 92),
#  ('ghostubusters', 92),
#  ('2ghostbusters', 92),
#  ('ghostbustersc', 92),
#  ('ghostbusters9', 92),
#  ('ghostbustsers', 92),
#  ('8ghostbusters', 92),
#  ('ghostbusers', 91),
#  ('ghosbusters', 91),
#  ('ghostbuters', 91),
#  ('ghostbustrs', 91),
#  ('ghostbustes', 91),
#  ('ghostbsters', 91),
#  ('ghstbusters', 91),
#  ('gostbusters', 91),
#  ('mezcoghostbusters', 90),
#  ('ownersghostbusters', 90),
#  ('ghostbustersanother', 90),
#  ('ghostbustersspice', 90),
#  ('animashghostbusters', 90),
#  ('guyghostbusterscourage', 90),
#  ('sivanghostbusters', 90),
#  ('paintingghostbusters', 90),
#  ('quotghostbustersquot', 90),
#  ('cutcaddyshackghostbusters', 90),
#  ('wwwarizonaghostbusterscomthis', 90),
#  ('spectrumghostbusters', 90)]

# %% [markdown]
# ## 3.4 **CYCLE 1** Creating Matcher and Matching Text Columns Against It

# %%
# creating a matcher to look for features that we care about: ghostbuster movie/film
def ghost_buster_related(list):
    label = 0
    if process.extractOne("ghostbuster", list, score_cutoff = 91) != None:
        label += 1
    if process.extractOne("movie", list, score_cutoff = 91) != None:
        label += 0.25
    if process.extractOne("film", list, score_cutoff = 100) != None:
        label += 0.25
    if process.extractOne("films", list, score_cutoff = 91) != None:
        label += 0.25
    return label

# %%
# using the matcher for the tokens of entire text data
# %%time
descriptions['first_tag_ghostbuster'] = descriptions['text_tokens'].apply(lambda x: ghost_buster_related(x))
# Out:
# CPU times: user 6min 34s, sys: 73.9 ms, total: 6min 34s
# Wall time: 6min 34s

# %%
# usint the matcher for the tokens of only title and description data
# %%time
descriptions['first_tag_ghostbuster_title_des'] = descriptions['title_des_tokens'].apply(lambda x: ghost_buster_related(x))
# Out:
# CPU times: user 4min 11s, sys: 35 ms, total: 4min 11s
# Wall time: 4min 11s

# %%
# yes, tag text data can be very misleading
descriptions[descriptions.first_tag_ghostbuster >= 1.25][descriptions['first_tag_ghostbuster_title_des'] < 1].head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                                    vid_id  \
# 56   594a6d24-f593-4461-ba3b-ea0a91083cb5
# 81   58dad7be-1605-47bd-b0a6-2c4e8eb6bcf8
# 85   58dbb2a0-5586-49ef-bfa2-e5a16a47310d
# 199  5955476e-a6d6-422d-a680-b5c57f491ee3
# 250  596a61a6-4407-4233-b4cc-46f4151cbbc9
#
#                                              vid_title  \
# 56                      Most Anticipated Films of 2016
# 81     Diamond Select Toys: Angry Burnt Stay Puft Bank
# 85           GHOST SLAMS DOORS INSIDE HAUNTED BUILDING
# 199                Nerd Block - August 2015 (Unboxing)
# 250  Surprise Packages - Twin Challenge Toys & Toy ...
#
#                                                    tag  \
# 56   'pixar', 'martin scorsese', 'finding nemo', 'm...
# 81   'Burn', 'Ghosts', '80s', 'toys', 'Film (Media ...
# 85   'abandon', 'halloween', 'Myth', 'ghost hunters...
# 199  'Nostalgia', 'Entertainment', 'Art', 'Tuan X',...
# 250  'boom boom balloon game', 'kids videos', 'Fan ...
#
#                                                vid_des  \
# 56   In which Emily gets lipstick on her teeth and ...
# 81   Order yours today: http://www.diamondselecttoy...
# 85   inside a haunted school and we been hearing di...
# 199  GET YOUR OWN BLOCK: http://j.mp/1SkDmzJ\n\nChe...
# 250  Surprise Packages - Twin Challenge Toys & Toy ...
#
#                     post_date                              owner_id  com_num  \
# 56  2016-01-25 21:17:34+00:00  59386f14-1f04-4b79-a2e1-b0a452f9e39d      0.0
# 81  2015-03-19 21:37:08+00:00  58d453f0-b82b-44ca-94ef-f9d00ec42a95     38.0
# 85  2015-03-09 22:41:27+00:00  58d3d8d9-ca5c-489f-99df-4de180ad2e28    888.0
# 199 2015-08-29 18:41:00+00:00  59300f30-01ed-46ca-b1d7-aa3ef00e045b     13.0
# 250 2017-03-30 13:02:57+00:00  596046f2-1000-4228-b7e3-411411d2094d    249.0
#
#      like_num  dis_num                                               text  \
# 56        6.0      4.0  'pixar', 'martin scorsese', 'finding nemo', 'm...
# 81       45.0      4.0  'Burn', 'Ghosts', '80s', 'toys', 'Film (Media ...
# 85     6416.0    161.0  'abandon', 'halloween', 'Myth', 'ghost hunters...
# 199      54.0      1.0  'Nostalgia', 'Entertainment', 'Art', 'Tuan X',...
# 250      67.0      0.0  'boom boom balloon game', 'kids videos', 'Fan ...
#
#                                         title_des_text  \
# 56   Most Anticipated Films of 2016 In which Emily ...
# 81   Diamond Select Toys: Angry Burnt Stay Puft Ban...
# 85   GHOST SLAMS DOORS INSIDE HAUNTED BUILDING insi...
# 199  Nerd Block - August 2015 (Unboxing) GET YOUR O...
# 250  Surprise Packages - Twin Challenge Toys & Toy ...
#
#                                            text_tokens  \
# 56   [pixar, martin, scorsese, finding, nemo, big, ...
# 81   [burn, ghosts, 80s, toys, film, media, genre, ...
# 85   [abandon, halloween, myth, ghost, hunters, par...
# 199  [nostalgia, entertainment, art, tuan, x, comed...
# 250  [boom, boom, balloon, game, kids, videos, fan,...
#
#                                       title_des_tokens  first_tag_ghostbuster  \
# 56   [anticipated, films, 2016, emily, gets, lipsti...                   1.75
# 81   [diamond, select, toys, angry, burnt, stay, pu...                   1.25
# 85   [ghost, slams, doors, inside, haunted, buildin...                   1.25
# 199  [nerd, block, august, 2015, unboxing, get, blo...                   1.25
# 250  [surprise, packages, twin, challenge, toys, to...                   1.25
#
#      first_tag_ghostbuster_title_des
# 56                              0.25
# 81                              0.00
# 85                              0.00
# 199                             0.00
# 250                             0.25

# %%
# creating a dataframe for clustering
descriptions_cycle_1 = descriptions[descriptions.first_tag_ghostbuster >= 1.25][descriptions['first_tag_ghostbuster_title_des'] >= 1]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
descriptions_cycle_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2397 entries, 46 to 38503
# Data columns (total 15 columns):
# vid_id                             2397 non-null object
# vid_title                          2397 non-null object
# tag                                2397 non-null object
# vid_des                            2397 non-null object
# post_date                          2397 non-null datetime64[ns, UTC]
# owner_id                           2397 non-null object
# com_num                            2247 non-null float64
# like_num                           2235 non-null float64
# dis_num                            2235 non-null float64
# text                               2397 non-null object
# title_des_text                     2397 non-null object
# text_tokens                        2397 non-null object
# title_des_tokens                   2397 non-null object
# first_tag_ghostbuster              2397 non-null float64
# first_tag_ghostbuster_title_des    2397 non-null float64
# dtypes: datetime64[ns, UTC](1), float64(5), object(9)
# memory usage: 299.6+ KB

# %% [markdown]
# ## 3.5 **CYCLE 1** Clustering Matches

# %%
#clustering to detect false friends of our initial features, especially ghostbuster
output_cols = []
n_clusters = 10
n_pca_groups = 50

corpus_cols = ['tag','vid_title','vid_des']

for ii, corpus_col in enumerate(corpus_cols):
    print(ii, corpus_col)
    print()
    print("1.Reading Corpus")
    corpus = list(descriptions_cycle_1.loc[:,corpus_col].apply(lambda x: normalize(x)))
    vectorizer = TfidfVectorizer(tokenizer=word_tokenize, stop_words=stop_words, 
                                 preprocessor=stemmer.stem, 
                                 ngram_range=(1,3))
    print("2.Fit Transform TF-IDF")
    X = vectorizer.fit_transform(corpus)
    tfidf_cols = list(vectorizer.get_feature_names())
    print("3.Create Dataframe")
    tfidf_df = pd.DataFrame(data=X.todense(), columns=vectorizer.get_feature_names())
    
    pca = PCA(n_components=n_pca_groups)
    print("4.Fit Transform PCA")
    pca_df = pca.fit_transform(tfidf_df)
    pca_df = pd.DataFrame(data=pca_df)
    
    print("5.Fit Transform KMeans")
    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(pca_df)
    pred = kmeans.predict(pca_df)
    cluster_col_name = '{}_cluster'.format(corpus_col)
    print("6.Write Data")
    pca_df[cluster_col_name] = pred
    descriptions_cycle_1[cluster_col_name] = pred
    tfidf_df[cluster_col_name] = pred
    
    output_cols.append(cluster_col_name)
    print("7.Print Summary")
    print(cluster_col_name)
    for x in np.unique(pred):
        temp = tfidf_df[tfidf_df.loc[:,cluster_col_name]==x].loc[:,tfidf_cols].sum()
        temp = temp.sort_values(ascending=False)
        print('Cluster {x}: {n} N'.format(x=x, n='{:,}'.format(np.sum(descriptions_cycle_1[cluster_col_name]==x))))
        print(temp[:20])
        print()
# Out:
# 0 tag
#
# 1.Reading Corpus
# 2.Fit Transform TF-IDF
# 3.Create Dataframe
# 4.Fit Transform PCA
# 5.Fit Transform KMeans
# 6.Write Data
# 7.Print Summary
# tag_cluster
# Cluster 0: 23 N
# toy                               2.427146
# reitman ghostbusters holtzmann    1.787148
# game toy                          1.787148
# harold ramis mattel               1.787148
# game toy fair                     1.787148
# marshmallow man sdcc              1.787148
# ramis mattel                      1.787148
# mccarthy diamond                  1.787148
# mccarthy diamond select           1.787148
# man sdcc                          1.787148
# york stream                       1.787148
# melissa mccarthy diamond          1.787148
# snl exclusive                     1.787148
# new york stream                   1.787148
# select                            1.761759
# ghostbusters holtzmann            1.761624
# neca                              1.761624
# figure ernie hudson               1.761624
# figure ernie                      1.761624
# scene leslie jones                1.749589
# dtype: float64
#
# Cluster 1: 235 N
# ghostbusters           21.447480
# review                 15.600337
# 2016                   15.250659
# ghostbusters 2016      13.018478
# movie                  11.010267
# movie review            9.220371
# mccarthy                8.902842
# melissa                 8.842530
# melissa mccarthy        8.839968
# leslie                  8.128270
# wiig                    7.827712
# kristen                 7.692819
# kate                    7.621866
# mckinnon                7.419416
# kate mckinnon           7.373018
# kristen wiig            7.325534
# review ghostbusters     6.761127
# leslie jones            6.734375
# jones                   6.641745
# trailer                 6.414317
# dtype: float64
#
# Cluster 2: 142 N
# ghostbusters                      21.576706
# trailer                           17.208841
# afterlife                         12.576413
# 2020                              11.464054
# ghostbusters afterlife            11.348334
# reaction                           8.773353
# ghostbusters 2020                  8.667931
# trailer ghostbusters               6.316311
# ghostbusters trailer               6.283826
# trailer reaction                   5.154001
# official                           4.757505
# paul rudd                          4.077581
# rudd                               4.077581
# 2020 ghostbusters                  4.051969
# movie                              3.996378
# afterlife trailer                  3.779192
# ghostbusters afterlife trailer     3.643636
# teaser                             3.521396
# ghostbusters ghostbusters          3.509217
# paul                               3.425438
# dtype: float64
#
# Cluster 3: 105 N
# lego                    34.043003
# dimensions              10.804704
# lego dimensions         10.523235
# lego ghostbusters        7.111842
# ghostbusters             4.796586
# ghostbusters lego        3.317077
# ecto1                    2.946228
# lego lego                2.667164
# dimensions lego          2.334604
# batman                   2.263803
# lego dimensions lego     2.254622
# game                     2.129114
# ninjago                  2.095496
# build                    1.986769
# pack                     1.947108
# lego batman              1.915750
# 21108                    1.884174
# brick                    1.843191
# review lego              1.825071
# ecto                     1.816300
# dtype: float64
#
# Cluster 4: 118 N
# kids               26.214425
# family              9.578906
# fortnite            8.652938
# fun                 8.101089
# scary               5.525296
# parody              5.477952
# gorgeous            4.823509
# skit                4.548857
# rangers             4.336305
# power rangers       4.235596
# power               4.164405
# movies              4.124146
# gorgeous movies     4.015501
# elf                 3.829403
# christmas           3.808706
# nerf                3.782844
# real life           3.707951
# funny               3.656994
# kids parody         3.655595
# spiderman           3.610356
# dtype: float64
#
# Cluster 5: 1,637 N
# ghostbusters         49.165650
# film                 32.922466
# movie                19.258478
# game                 17.374643
# review               16.609780
# ghostbusters film    16.385589
# ghostbust            13.632309
# movies               13.581575
# trailer              11.371289
# 2016                 11.137572
# ecto                 11.113730
# tv                   10.380547
# ghost                 9.926557
# bill                  9.420980
# new                   9.099655
# murray                8.708557
# ecto1                 8.403966
# games                 8.198496
# dan                   7.920939
# genre                 7.876618
# dtype: float64
#
# Cluster 6: 34 N
# show unboxing slime            2.821003
# board pop                      2.821003
# tour funko                     2.821003
# tour funko reboot              2.821003
# harold ramis ivan              2.821003
# show unboxing                  2.821003
# pop vinyl fan                  2.821003
# ramis ivan                     2.821003
# ramis ivan mattel              2.821003
# board pop vinyl                2.821003
# ivan mattel                    2.821003
# vinyl fan                      2.821003
# vinyl fan fest                 2.821003
# unboxing slime                 2.805800
# halloween proton pack          2.805800
# pack action figures            2.805800
# halloween proton               2.805800
# unboxing slime ghostbusters    2.805800
# pack action                    2.791013
# proton pack action             2.791013
# dtype: float64
#
# Cluster 7: 86 N
# afterlife                              21.758868
# ghostbusters afterlife                 21.134248
# ghostbusters                           16.837843
# trailer                                16.713969
# reaction                               15.841820
# trailer reaction                       12.210913
# afterlife trailer                      11.821593
# reaction ghostbusters                  11.658559
# ghostbusters afterlife trailer         11.457607
# 2020                                    8.392831
# trailer reaction ghostbusters           8.190618
# ghostbusters 2020                       7.439410
# reaction ghostbusters afterlife         7.327057
# trailer ghostbusters                    5.494076
# afterlife trailer reaction              5.182078
# afterlife ghostbusters                  4.160637
# ghostbusters afterlife ghostbusters     3.920149
# ghostbusters trailer                    3.892860
# 2020 trailer                            3.587942
# ghostbusters trailer reaction           3.402372
# dtype: float64
#
# Cluster 8: 10 N
# ghostbusters                         4.047581
# full movie ghostbusters              1.775060
# song ghostbusters                    1.582414
# full movie                           1.527461
# full                                 1.365123
# song                                 1.241885
# movie ghostbusters                   1.118209
# remix ghostbusters fall              0.932847
# scene ghostbusters full              0.932847
# cartoon ghostbusters 2016            0.932847
# ghostbusters ghostbusters kate       0.932847
# mccarthy ghostbusters theme          0.932847
# ghostbusters cartoon ghostbusters    0.932847
# movie ghostbusters trail             0.932847
# hemsworth ghostbusters honest        0.932847
# ghostbusters 2016 full               0.932847
# wiig ghostbusters clip               0.932847
# mckinnon ghostbusters leslie         0.932847
# jones ghostbusters cartoon           0.932847
# clip ghostbusters chris              0.932847
# dtype: float64
#
# Cluster 9: 7 N
# 1959                            1.081041
# model                           0.961132
# cadillac                        0.917489
# ecto1                           0.700925
# 1959 cadillac millermeteor      0.626109
# 1959 bill                       0.626109
# futura                          0.626109
# futura duplex                   0.626109
# futura duplex spengler          0.626109
# hero collector zeddemore        0.626109
# cadillac millermeteor futura    0.626109
# cadillac millermeteor           0.626109
# collector zeddemore             0.626109
# millermeteor futura             0.626109
# duplex spengler ivan            0.626109
# duplex spengler                 0.626109
# duplex                          0.626109
# spengler ivan                   0.626109
# spengler ivan reitman           0.626109
# millermeteor futura duplex      0.626109
# dtype: float64
#
# 1 vid_title
#
# 1.Reading Corpus
# 2.Fit Transform TF-IDF
# 3.Create Dataframe
# 4.Fit Transform PCA
# 5.Fit Transform KMeans
# 6.Write Data
# 7.Print Summary
# vid_title_cluster
# Cluster 0: 1,945 N
# ghostbusters          69.888313
# review                32.888941
# 2016                  30.862112
# movie                 25.102678
# ghostbusters 2016     22.590610
# trailer               19.331553
# ghostbust             17.619787
# new                   15.286976
# game                  14.567267
# kids                  12.578446
# ecto1                 12.275045
# part                  11.292547
# real                  10.860605
# react                  9.569454
# ghostbusters game      9.548050
# ecto                   9.417319
# vs                     9.300194
# trail                  9.242523
# ghostbusters ecto1     8.967060
# 1984                   8.950638
# dtype: float64
#
# Cluster 1: 102 N
# trailer                           13.927458
# afterlife                         13.344145
# ghostbusters afterlife            13.280668
# trailer reaction                  12.692920
# afterlife trailer                 12.431856
# ghostbusters afterlife trailer    12.303387
# reaction                          12.248677
# afterlife trailer reaction         7.986128
# ghostbusters                       7.110786
# 2020                               5.006131
# trailer reaction review            4.210882
# reaction review                    4.042377
# ghostbusters trailer reaction      3.212088
# review                             2.727595
# ghostbusters trailer               2.549377
# ghostbusters afterlife 2020        2.200545
# afterlife 2020                     2.177165
# official                           2.124615
# react                              2.117462
# reaction ghostbusters              1.921891
# dtype: float64
#
# Cluster 2: 62 N
# official trailer                   18.120649
# official trailer react             17.290896
# official                           17.270792
# afterlife official trailer         16.091076
# ghostbusters afterlife official    15.923610
# afterlife official                 15.923610
# trailer react                      14.556839
# react                              13.624536
# trailer                            12.575718
# ghostbusters afterlife             12.102967
# afterlife                          12.023702
# ghostbusters                        6.002177
# ghostbusters official trailer       4.014642
# ghostbusters official               3.953264
# official trailer reaction           2.474005
# trailer reaction                    1.862341
# reaction                            1.693726
# 2020                                1.593324
# trailer reaction review             1.403867
# reaction review                     1.347689
# dtype: float64
#
# Cluster 3: 36 N
# 2016 movie review             14.576887
# ghostbusters 2016 movie       13.826039
# 2016 movie                    13.826039
# movie review                  12.012414
# ghostbusters 2016              9.533844
# movie                          9.049154
# 2016                           8.529105
# review                         7.722855
# ghostbusters                   3.998467
# review good                    0.378141
# review good bad                0.378141
# movie review good              0.378141
# nonspoiler nerdsoul            0.363550
# movie review nonspoiler        0.363550
# review nonspoiler nerdsoul     0.363550
# review nonspoiler              0.363550
# nonspoiler                     0.363550
# movie review spoiler           0.363084
# review spoiler fre             0.363084
# busters ghostbusters           0.360057
# dtype: float64
#
# Cluster 4: 34 N
# ghostbusters 2016 review          11.961886
# 2016 review                       11.828730
# ghostbusters 2016                  8.961501
# 2016                               8.017079
# review                             6.111934
# ghostbusters                       3.811798
# spoiler                            0.823987
# refus                              0.768760
# 2016 review refus                  0.768760
# review refus                       0.768760
# spoil                              0.656018
# spoiler heavi                      0.625248
# heavi                              0.625248
# talk                               0.617065
# 2016 review spoil                  0.521261
# announcement ghostbusters 2016     0.501472
# 2016 review votesaxon07            0.494316
# projector ghostbusters             0.488517
# projector ghostbusters 2016        0.488517
# afterthought ghostbusters          0.482917
# dtype: float64
#
# Cluster 5: 148 N
# lego                            22.832929
# lego ghostbusters               10.502064
# lego dimensions                  9.737370
# dimensions                       9.737370
# ecto1                            6.076762
# 21108                            5.361633
# ghostbusters                     4.780314
# ghostbusters ecto1               4.741257
# lego ghostbusters ecto1          4.474203
# walkthrough                      3.971589
# part                             3.662929
# walkthrough part                 3.323440
# build                            3.223227
# 75828                            3.183013
# set                              3.040677
# lego dimensions ghostbusters     2.940925
# dimensions ghostbusters          2.940925
# review                           2.896932
# speed                            2.532820
# gameplay                         2.516689
# dtype: float64
#
# Cluster 6: 8 N
# ghostbusters review              6.520402
# review                           3.245439
# ghostbusters                     1.703320
# ghostbusters review 2016         0.632797
# review 2016                      0.561118
# 2016                             0.233138
# firehouse cinemat                0.000000
# firehouse                        0.000000
# firehouse 1987                   0.000000
# firehouse abandon                0.000000
# firehouse banquet                0.000000
# firehouse banquet room           0.000000
# zuul gate keeper                 0.000000
# firehous                         0.000000
# firehouse headquarters 21108     0.000000
# firehouse headquarters 75827     0.000000
# firehouse headquarters ecto1     0.000000
# firehouse headquarters lego      0.000000
# firehouse headquarters moc       0.000000
# firehouse headquarters review    0.000000
# dtype: float64
#
# Cluster 7: 33 N
# afterlife trailer react           15.049867
# afterlife trailer                 11.998536
# trailer react                     11.805597
# ghostbusters afterlife trailer    11.792131
# react                             10.765348
# afterlife                          9.641593
# ghostbusters afterlife             9.492642
# trailer                            8.428428
# ghostbusters                       3.934660
# ghostbuster afterlife              0.509996
# ghostbuster afterlife trailer      0.509996
# hordie                             0.450504
# hordie ghostbusters                0.450504
# hordie ghostbusters afterlife      0.450504
# ghostbuster                        0.318050
# firehouse cinemat                  0.000000
# firehouse banquet room             0.000000
# firehouse banquet                  0.000000
# firehouse                          0.000000
# firehouse headquarters 21108       0.000000
# dtype: float64
#
# Cluster 8: 9 N
# haunting                      2.166267
# fan film idea                 2.166267
# haunting hour                 2.166267
# idea                          2.166267
# ghostbusters haunting         2.166267
# hour                          2.166267
# ghostbusters haunting hour    2.166267
# film idea                     2.166267
# fan film                      2.053781
# film idea part                1.967910
# hour fan                      1.967910
# haunting hour fan             1.967910
# hour fan film                 1.967910
# idea part                     1.967910
# fan                           1.873589
# film                          1.628215
# part                          1.209163
# ghostbusters                  0.467085
# full fan                      0.286932
# full fan film                 0.286932
# dtype: float64
#
# Cluster 9: 20 N
# ghostbusters movie review       11.354823
# ghostbusters movie               9.567033
# movie review                     8.504306
# movie                            6.406437
# review                           5.393608
# ghostbusters                     2.830754
# movie review 2016                0.550238
# movie review spoil               0.495459
# review 2016                      0.487911
# review spoil                     0.462520
# spoil                            0.406069
# 2016                             0.202721
# firehouse 1987                   0.000000
# firehouse abandon                0.000000
# firehouse banquet                0.000000
# firehouse banquet room           0.000000
# zuul gate keeper                 0.000000
# firehouse cinemat                0.000000
# firehouse headquarters 21108     0.000000
# firehouse headquarters 75827     0.000000
# dtype: float64
#
# 2 vid_des
#
# 1.Reading Corpus
# 2.Fit Transform TF-IDF
# 3.Create Dataframe
# 4.Fit Transform PCA
# 5.Fit Transform KMeans
# 6.Write Data
# 7.Print Summary
# vid_des_cluster
# Cluster 0: 207 N
# trailer                           12.860743
# ghostbusters                       7.789414
# afterlife                          7.283964
# ghostbusters afterlife             7.087854
# reaction                           5.789953
# ross                               4.142231
# info join                          3.690730
# 2020                               3.599140
# movie                              3.562065
# pencilmation                       3.427071
# afterlife trailer                  3.407952
# trailer reaction                   3.406049
# official trailer                   3.382388
# ghostbusters afterlife trailer     3.346620
# official                           3.276981
# trailer ghostbusters               3.215862
# info                               3.012968
# new                                2.991797
# paul                               2.865111
# 2016                               2.680593
# dtype: float64
#
# Cluster 1: 15 N
# lego                2.805173
# dimensions          2.588621
# lego dimensions     2.101512
# pack                1.492314
# franchises          1.239636
# wii u               1.231655
# wii                 1.182475
# level               1.182419
# cover               1.146047
# u                   1.117042
# game                1.096544
# xbox                1.091899
# include             1.055872
# future              1.033827
# packs               1.016967
# level pack          0.764639
# pack level pack     0.761591
# pack level          0.754274
# final               0.745729
# cover characters    0.724866
# dtype: float64
#
# Cluster 2: 140 N
# daniel             13.906633
# gorgeous           12.707658
# parodies           12.330936
# entertain          12.234589
# family             11.810578
# david              11.648706
# boys               11.566180
# videos              9.595050
# one                 8.633192
# subscribers         7.495209
# harry               6.741042
# charlie             6.661695
# power               6.631149
# gorgeous movies     6.576559
# ranger              6.537265
# crazy               6.535621
# lego                6.513703
# janet               6.471382
# david janet         6.235591
# fun videos          6.213029
# dtype: float64
#
# Cluster 3: 11 N
# birds                1.135120
# key                  0.815882
# entirely             0.781349
# island               0.775657
# sisters              0.769800
# hecox                0.674911
# ian hecox anthony    0.674911
# ian hecox            0.674911
# hecox anthony        0.674911
# ian                  0.637582
# produced             0.613492
# anthony              0.592047
# hed                  0.577794
# angry                0.556168
# hale                 0.547843
# peter dinklage       0.547843
# dinklage             0.547843
# sudeikis             0.547843
# mcbride              0.540880
# cohen                0.530114
# dtype: float64
#
# Cluster 4: 46 N
# facts                   18.643267
# quick                   16.637934
# interesting              7.795597
# interesting facts        6.739043
# 30                       5.199124
# bbtv                     4.768931
# quick facts              4.659320
# upcoming                 3.299666
# 30 quick facts           3.209511
# 30 quick                 3.209511
# facts finding            3.209511
# facts 30                 3.209511
# interesting facts 30     3.209511
# finding                  2.794033
# trailers                 2.419054
# bbtv trailers            2.242126
# movies                   1.893304
# shows                    1.708520
# partners                 1.701757
# tv shows                 1.685202
# dtype: float64
#
# Cluster 5: 26 N
# paul feig                   2.125776
# feig                        2.114774
# kristen wiig kate           1.963985
# wiig kate                   1.946518
# wiig kate mckinnon          1.946518
# mccarthy kristen wiig       1.921693
# mccarthy kristen            1.913754
# melissa mccarthy kristen    1.913754
# paul                        1.822553
# mckinnon leslie jones       1.721776
# mckinnon leslie             1.721776
# kate mckinnon leslie        1.721776
# melissa mccarthy            1.720142
# mccarthy                    1.716075
# melissa                     1.704110
# kristen wiig                1.682790
# wiig                        1.661545
# kristen                     1.653359
# chris                       1.645740
# world                       1.633889
# dtype: float64
#
# Cluster 6: 1,877 N
# ghostbusters          35.756888
# movie                 25.155273
# new                   19.103197
# lego                  18.458816
# review                16.075149
# game                  12.653068
# film                  11.371078
# music                 11.050521
# get                   10.673659
# 2016                  10.498498
# new ghostbusters       9.797970
# ecto1                  9.431498
# ghostbusters movie     9.391123
# one                    9.122333
# also                   8.910503
# videos                 8.689471
# join                   8.448382
# time                   8.441804
# see                    8.429061
# page                   7.901292
# dtype: float64
#
# Cluster 7: 22 N
# reitman                   3.584757
# jason                     2.609078
# jason reitman             2.476225
# original ghostbusters     1.784094
# gil kenan                 1.772688
# gil                       1.761590
# afterlife                 1.731085
# kenan                     1.701905
# written                   1.565083
# ivan reitman              1.520015
# ghostbusters afterlife    1.514890
# ivan                      1.476573
# film written              1.403222
# ghostbusters              1.396220
# original                  1.357714
# small town begin          1.244678
# kids arrive small         1.244678
# arrive small town         1.244678
# arrive small              1.244678
# two kids arrive           1.244678
# dtype: float64
#
# Cluster 8: 10 N
# movie                          1.314802
# fans movie                     1.071275
# movie fans                     1.071275
# movie fans movie               1.071275
# fandango                       1.045052
# movieclips                     1.033315
# trailers                       1.006918
# movie clips                    0.939746
# description                    0.889180
# clips                          0.764129
# fans                           0.750692
# film                           0.618665
# hunky                          0.596136
# receptionist                   0.580538
# movie games                    0.543038
# tm sony                        0.543038
# movie games fandango           0.543038
# bridesmaids directed           0.543038
# bridesmaids directed reboot    0.543038
# indie film festivals           0.543038
# dtype: float64
#
# Cluster 9: 43 N
# use                               6.670277
# fair                              4.935555
# fair use                          4.884948
# disclaimer                        2.140064
# purposes criticism                2.043952
# scholarship                       2.035371
# use purposes criticism            2.035203
# reporting teaching                2.026963
# news reporting teaching           2.026963
# reporting teaching scholarship    2.026367
# criticism                         2.020149
# teaching scholarship              2.017718
# made fair use                     2.017718
# allowance made fair               2.009246
# allowance                         2.009246
# use purposes                      2.009246
# allowance made                    2.009246
# fair use purposes                 2.009246
# news reporting                    2.002712
# research fair use                 1.998897
# dtype: float64

# %%
# removing videos of the very irrelevant clusters
tag = [1,2,5,7,8]
title = [0,1,2,3,4,7,9]
des = [0,5,6,7,9]
descriptions_cycle_2 = descriptions_cycle_1[descriptions_cycle_1['tag_cluster'].isin(tag)][descriptions_cycle_1['vid_title_cluster'].isin(title)][descriptions_cycle_1['vid_des_cluster'].isin(des)]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %% [markdown]
# ## 3.6 **CYCLE 2** Editing the Matcher and Rematching

# %%
# updating the matcher with a better idea on the false friends of ghostbusters
def ghost_buster_related_2(list):
    label = 0
    if process.extractOne("ghostbuster", list, score_cutoff = 91) != None:
        label += 1
        
    important_words = ['movie','movies','film','films','afterlife','review','trailer']
    for w in important_words:
        if process.extractOne(w, list, score_cutoff = 100) != None:
            label += 0.25
        
    punished_words = {'halloween':80,'dimensions':95,'paranormal':90,'haunted':92,'game':89,'pokemon':100,'toy':86,'ecto1':100,'ecto':100,'lego':85,'wellness':85,'comic':100,'book':100}
    for key, value in punished_words.items():
        if process.extractOne(key, list, score_cutoff = value) != None:
            label -= 5
    return label

# %%
# %%time
# matching
descriptions_cycle_2.loc[:,'second_tag_ghostbuster'] = descriptions_cycle_2.loc[:,'text_tokens'].apply(lambda x: ghost_buster_related_2(x))
# Out:
# CPU times: user 1min 55s, sys: 11.5 ms, total: 1min 55s
# Wall time: 1min 55s

# %%
descriptions_cycle_2 = descriptions_cycle_2[descriptions_cycle_2.second_tag_ghostbuster >= 1.25]

# %%
descriptions_cycle_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 879 entries, 46 to 38503
# Data columns (total 19 columns):
# vid_id                             879 non-null object
# vid_title                          879 non-null object
# tag                                879 non-null object
# vid_des                            879 non-null object
# post_date                          879 non-null datetime64[ns, UTC]
# owner_id                           879 non-null object
# com_num                            775 non-null float64
# like_num                           774 non-null float64
# dis_num                            774 non-null float64
# text                               879 non-null object
# title_des_text                     879 non-null object
# text_tokens                        879 non-null object
# title_des_tokens                   879 non-null object
# first_tag_ghostbuster              879 non-null float64
# first_tag_ghostbuster_title_des    879 non-null float64
# tag_cluster                        879 non-null int32
# vid_title_cluster                  879 non-null int32
# vid_des_cluster                    879 non-null int32
# second_tag_ghostbuster             879 non-null float64
# dtypes: datetime64[ns, UTC](1), float64(6), int32(3), object(9)
# memory usage: 127.0+ KB

# %%
descriptions_cycle_2.head()
# Out:
#                                    vid_id  \
# 46   5e6fe266-c9e3-4630-8e7e-0d3b752e126a
# 267  594a6c89-8320-42a7-981f-a7f0394d599e
# 358  591200f2-0f97-42bc-ae85-c44b6d8aa152
# 379  5e6fe265-824d-46b3-ac20-f7faddd38b04
# 386  59531532-6bcb-4834-94da-9f6ccc1dceae
#
#                                              vid_title  \
# 46                        Ghostbusters Spoilers Review
# 267             Back to the 80s ... Ghostbuster (1984)
# 358  Ghostbusters 2016 Trailer Final Thoughts/Sony ...
# 379                        Ghostbusters - Movie Review
# 386                Ghostbusters (Wright at the Movies)
#
#                                                    tag  \
# 46   'Movie Talk', 'comedy', 'spoilers', 'melissa m...
# 267  'Trailer', 'Music', 'KiKoo Village', 'Ghostbus...
# 358
# 379  'Trailer', 'Teaser', 'Paul Feig', '1989', 'Sou...
# 386  'ghostbusters review', 'mistr wright', 'review...
#
#                                                vid_des  \
# 46   Jon Schnepp, Wendy Lee and Jason Inman give th...
# 267
# 358  Wwe: Why Superstars Are Getting Injuries https...
# 379  FACEBOOK: https://www.facebook.com/ChrisStuckm...
# 386  2014 is the 30th anniversary of Ghostbusters, ...
#
#                     post_date                              owner_id  com_num  \
# 46  2016-07-15 16:00:08+00:00  5beb1491-f2bc-4b43-91df-44777cfbe800    301.0
# 267 2012-03-14 16:25:59+00:00  59386f01-168f-4f02-9dc1-ef47c2e389d7      0.0
# 358 2016-03-21 03:45:03+00:00  590a6b84-de6a-4975-bad5-08bb9bd79f27      NaN
# 379 2016-07-13 07:58:14+00:00  58d40d52-49e2-41c0-ade9-f85e36b9ab7b   9158.0
# 386 2014-09-10 15:10:42+00:00  59300f2b-e00f-4045-af83-fb4eeb9ac866      0.0
#
#      like_num  dis_num                                               text  \
# 46      542.0    336.0  'Movie Talk', 'comedy', 'spoilers', 'melissa m...
# 267       0.0      0.0  'Trailer', 'Music', 'KiKoo Village', 'Ghostbus...
# 358       NaN      NaN   Ghostbusters 2016 Trailer Final Thoughts/Sony...
# 379   32130.0   6205.0  'Trailer', 'Teaser', 'Paul Feig', '1989', 'Sou...
# 386       2.0      0.0  'ghostbusters review', 'mistr wright', 'review...
#
#                                         title_des_text  \
# 46   Ghostbusters Spoilers Review Jon Schnepp, Wend...
# 267           Back to the 80s ... Ghostbuster (1984)
# 358  Ghostbusters 2016 Trailer Final Thoughts/Sony ...
# 379  Ghostbusters - Movie Review FACEBOOK: https://...
# 386  Ghostbusters (Wright at the Movies) 2014 is th...
#
#                                            text_tokens  \
# 46   [movie, talk, comedy, spoilers, melissa, mccar...
# 267  [trailer, music, kikoo, village, ghostbuster, ...
# 358  [ghostbusters, 2016, trailer, final, thoughtss...
# 379  [trailer, teaser, paul, feig, 1989, soundtrack...
# 386  [ghostbusters, review, mistr, wright, review, ...
#
#                                       title_des_tokens  first_tag_ghostbuster  \
# 46   [ghostbusters, spoilers, review, jon, schnepp,...                   1.50
# 267                     [back, 80s, ghostbuster, 1984]                   1.25
# 358  [ghostbusters, 2016, trailer, final, thoughtss...                   1.25
# 379  [ghostbusters, movie, review, official, site, ...                   1.50
# 386  [ghostbusters, wright, movies, 2014, 30th, ann...                   1.50
#
#      first_tag_ghostbuster_title_des  tag_cluster  vid_title_cluster  \
# 46                              1.25            1                  0
# 267                             1.00            5                  0
# 358                             1.25            5                  0
# 379                             1.25            1                  9
# 386                             1.25            5                  0
#
#      vid_des_cluster  second_tag_ghostbuster
# 46                 6                    2.25
# 267                6                    1.50
# 358                6                    1.50
# 379                5                    2.00
# 386                6                    2.00

# %% [markdown]
# ## 3.7 **CYCLE 2** Clustering Matches

# %%
output_cols = []
n_clusters = 10
n_pca_groups = 50

corpus_cols = ['tag','vid_title','vid_des']

for ii, corpus_col in enumerate(corpus_cols):
    print(ii, corpus_col)
    print()
    print("1.Reading Corpus")
    corpus = list(descriptions_cycle_2[corpus_col].apply(lambda x: normalize(x)))
    vectorizer = TfidfVectorizer(tokenizer=word_tokenize, stop_words=stop_words, 
                                 preprocessor=stemmer.stem, 
                                 ngram_range=(1,2))
    print("2.Fit Transform TF-IDF")
    X = vectorizer.fit_transform(corpus)
    tfidf_cols = list(vectorizer.get_feature_names())
    print("3.Create Dataframe")
    tfidf_df = pd.DataFrame(data=X.todense(), columns=vectorizer.get_feature_names())
    
    pca = PCA(n_components=n_pca_groups)
    print("4.Fit Transform PCA")
    pca_df = pca.fit_transform(tfidf_df)
    pca_df = pd.DataFrame(data=pca_df)
    
    print("5.Fit Transform KMeans")
    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(pca_df)
    pred = kmeans.predict(pca_df)
    cluster_col_name = '{}_cluster'.format(corpus_col)
    print("6.Write Data")
    pca_df[cluster_col_name] = pred
    descriptions_cycle_2[cluster_col_name] = pred
    tfidf_df[cluster_col_name] = pred
    
    output_cols.append(cluster_col_name)
    print("7.Print Summary")
    print(cluster_col_name)
    for x in np.unique(pred):
        temp = tfidf_df[tfidf_df[cluster_col_name]==x][tfidf_cols].sum()
        temp = temp.sort_values(ascending=False)
        print('Cluster {x}: {n} N'.format(x=x, n='{:,}'.format(np.sum(descriptions_cycle_2[cluster_col_name]==x))))
        print(temp[:20])
        print()
# Out:
# 0 tag
#
# 1.Reading Corpus
# 2.Fit Transform TF-IDF
# 3.Create Dataframe
# 4.Fit Transform PCA
# 5.Fit Transform KMeans
# 6.Write Data
# 7.Print Summary
# tag_cluster
# Cluster 0: 59 N
# bill            4.561238
# murray          4.550293
# dan             4.406987
# aykroyd         4.014421
# ghostbusters    3.853289
# bill murray     3.834275
# harold          3.565409
# ramis           3.551187
# dan aykroyd     3.507314
# harold ramis    2.963175
# film            2.708839
# sigourney       2.704243
# weaver          2.610296
# hudson          2.512938
# ernie           2.512938
# ernie hudson    2.426427
# actor           2.237655
# moranis         2.080547
# rick            2.047391
# reitman         2.012471
# dtype: float64
#
# Cluster 1: 22 N
# ghostbusters                 5.570306
# 2020                         3.801863
# trailer                      2.907250
# ghostbusters 2020            2.511485
# teaser                       2.125738
# ghostbusters teaser          1.553135
# 2020 ghostbusters            1.546972
# movie                        1.465712
# trailers                     1.435491
# ghostbusters trailer         1.373080
# new                          1.257152
# reaction                     1.256817
# movies                       1.217560
# ghostbusters ghostbusters    1.163739
# trailer ghostbusters         1.152551
# teaser trailer               1.057799
# afterlife                    0.982313
# ghostbusters afterlife       0.958914
# news                         0.948870
# jason reitman                0.883356
# dtype: float64
#
# Cluster 2: 53 N
# ghostbusters                 9.526194
# review                       9.111915
# 2016                         8.161774
# ghostbusters 2016            7.546410
# movie review                 5.556966
# movie                        5.485933
# review ghostbusters          4.033378
# ghostbusters movie           3.134459
# ghostbusters review          3.118431
# review movie                 2.186614
# 2016 ghostbusters            1.986350
# 2016 review                  1.919441
# reboot                       1.808570
# 2016 movie                   1.761852
# ghostbusters ghostbusters    1.455488
# rant                         1.448231
# trailer                      1.293770
# ghostbusters 1984            1.285563
# reviews                      1.223718
# 1984                         1.095521
# dtype: float64
#
# Cluster 3: 73 N
# leslie              5.623845
# mccarthy            5.615037
# melissa             5.566773
# melissa mccarthy    5.535761
# kristen             4.807523
# wiig                4.724503
# jones               4.591209
# ghostbusters        4.564490
# kristen wiig        4.505895
# leslie jones        4.504881
# kate                4.349096
# kate mckinnon       4.254360
# mckinnon            4.237272
# chris               3.929093
# chris hemsworth     3.780458
# review              3.773675
# hemsworth           3.759546
# feig                3.752623
# movie               3.724165
# paul feig           3.715454
# dtype: float64
#
# Cluster 4: 30 N
# afterlife                 7.529333
# ghostbusters afterlife    7.491500
# ghostbusters              7.484556
# 2020                      4.452553
# trailer                   4.270459
# ghostbusters 2020         3.530169
# afterlife trailer         2.365341
# trailer ghostbusters      1.881269
# rudd                      1.875857
# paul rudd                 1.875857
# finn wolfhard             1.742716
# wolfhard                  1.733076
# finn                      1.733076
# afterlife ghostbusters    1.615698
# paul                      1.543731
# reaction                  1.447243
# reitman                   1.346376
# 2020 ghostbusters         1.337362
# jason reitman             1.248888
# jason                     1.236038
# dtype: float64
#
# Cluster 5: 18 N
# ghostbust              8.042256
# imovie                 0.781896
# 2016 ghostbust         0.746449
# movies ghostbust       0.643862
# reboot ghostbust       0.588946
# reaction afterlife     0.582247
# afterlife ghostbust    0.582247
# ghostbusters reboot    0.580084
# review movies          0.560614
# funny ghostbust        0.551203
# imovie funny           0.551203
# sony                   0.505229
# dancing toaster        0.493055
# toaster                0.493055
# toaster ghostbust      0.493055
# sony ghostbusters      0.463950
# movies                 0.453381
# feige ghost            0.445267
# ghost ghostbust        0.445267
# reboot                 0.438718
# dtype: float64
#
# Cluster 6: 55 N
# trailer                  10.089093
# ghostbusters              7.904555
# reaction                  5.449474
# ghostbusters trailer      4.927204
# movie                     3.295779
# trailer reaction          3.056887
# official                  2.770685
# new                       2.509213
# trailer ghostbusters      2.362225
# review                    1.904679
# 2016                      1.857196
# ghostbusters official     1.856167
# movie trailer             1.786157
# trailer trailer           1.783379
# official trailer          1.769854
# afterlife                 1.728945
# reaction ghostbusters     1.659856
# horror                    1.362257
# new trailer               1.329253
# movie ghostbusters        1.307182
# dtype: float64
#
# Cluster 7: 52 N
# afterlife                 15.105211
# ghostbusters afterlife    14.812993
# ghostbusters              13.684528
# trailer                   13.323491
# reaction                  12.290927
# trailer reaction           9.477982
# reaction ghostbusters      8.735226
# afterlife trailer          8.710469
# 2020                       6.375108
# ghostbusters 2020          5.513943
# trailer ghostbusters       4.313570
# ghostbusters trailer       3.299829
# afterlife ghostbusters     3.005544
# 2020 trailer               2.914949
# trailer review             2.178815
# 2020 ghostbusters          2.170220
# rudd                       2.160503
# paul rudd                  2.160503
# trail                      2.088080
# official                   2.012365
# dtype: float64
#
# Cluster 8: 37 N
# film                     7.737704
# ghostbusters film        5.246084
# ghostbusters             3.248045
# genre                    2.869425
# subject                  2.784113
# film subject             2.671206
# ventriloquism film       2.355194
# ventriloquism            2.314212
# media                    2.131054
# media genre              1.805408
# work                     1.781881
# film ventriloquism       1.733070
# awardwinning             1.671813
# awardwinning work        1.671813
# film media               1.652667
# composit                 1.581513
# ghostbusters composit    1.581513
# subject ghostbusters     1.514257
# tv                       1.483156
# film character           1.276205
# dtype: float64
#
# Cluster 9: 480 N
# ghostbusters         13.777763
# film                  7.832430
# movie                 7.161428
# movies                6.753838
# review                4.479705
# 2016                  4.444354
# trailer               4.437886
# funny                 3.095996
# animation             2.992232
# news                  2.911582
# cartoon               2.870962
# ghost                 2.845213
# ghostbusters 2016     2.685215
# music                 2.668483
# reaction              2.652123
# song                  2.627364
# comedy                2.620861
# ghostbusters film     2.619793
# pop                   2.553609
# theme                 2.523071
# dtype: float64
#
# 1 vid_title
#
# 1.Reading Corpus
# 2.Fit Transform TF-IDF
# 3.Create Dataframe
# 4.Fit Transform PCA
# 5.Fit Transform KMeans
# 6.Write Data
# 7.Print Summary
# vid_title_cluster
# Cluster 0: 64 N
# trailer                   11.030901
# trailer reaction          10.563294
# afterlife                 10.367727
# reaction                  10.362428
# ghostbusters afterlife    10.215421
# afterlife trailer          9.675191
# ghostbusters               6.232267
# ghostbusters trailer       4.154131
# 2020                       3.985378
# review                     3.809784
# reaction review            3.639392
# trailer review             3.620068
# rudd                       2.298452
# paul rudd                  2.298452
# trailer 2020               2.153494
# paul                       2.101225
# reaction ghostbusters      1.893627
# trail                      1.773015
# afterlife trail            1.639599
# thoughts                   1.456116
# dtype: float64
#
# Cluster 1: 573 N
# ghostbusters              27.191283
# movie                     10.501984
# trailer                    9.520077
# new                        9.377920
# review                     9.000992
# ghostbust                  6.823262
# 2020                       6.233590
# new ghostbusters           5.572242
# trail                      5.425527
# ghostbusters trailer       5.256612
# 2016                       4.884428
# ghostbusters movie         4.658122
# ghostbuster                4.535110
# react                      4.501144
# teaser                     4.175160
# theme                      4.132550
# hd                         3.970054
# ghostbusters afterlife     3.882909
# afterlife                  3.873127
# vs                         3.869295
# dtype: float64
#
# Cluster 2: 42 N
# official trailer          14.577119
# official                  14.411896
# afterlife official        12.826463
# trailer react             11.050109
# react                     10.609536
# ghostbusters afterlife     9.617362
# afterlife                  9.593133
# trailer                    9.584726
# ghostbusters               5.148041
# ghostbusters official      3.229634
# 2020                       2.044525
# trailer reaction           1.502941
# 2020 official              1.465040
# reaction                   1.355585
# afterlife 2020             1.275874
# trailer hd                 0.976484
# reaction review            0.880811
# trailer cinemas            0.838737
# cinemas                    0.802623
# hd                         0.764611
# dtype: float64
#
# Cluster 3: 10 N
# ghostbusters ii       3.418155
# ii                    3.312058
# ii 1989               1.674080
# 1989                  1.624615
# 1989 movie            1.358757
# review                0.904156
# vhs                   0.796153
# ghostbusters          0.796058
# movie                 0.746920
# movie review          0.744503
# ii bluray             0.520640
# ii vhs                0.497768
# vhs review            0.497768
# bluray review         0.469717
# dancing toast         0.456601
# ii dancing            0.456601
# dancing               0.430477
# vhs trail             0.416610
# 1989 vhs              0.416610
# fanscription react    0.405579
# dtype: float64
#
# Cluster 4: 19 N
# ghostbusters 1984      5.255936
# 1984                   4.743275
# ghostbust              3.459470
# 1984 movie             2.887228
# movie review           2.463741
# movie                  2.123639
# review                 2.039909
# ghostbusters           1.347349
# vs 2016                0.776919
# 1984 vs                0.776919
# review ghostbust       0.690641
# classic                0.576668
# vs                     0.575420
# review ghostbusters    0.504488
# 1984 title             0.482236
# live commentari        0.469217
# 1984 live              0.469217
# commentari             0.469217
# title sequ             0.454645
# creatur                0.451984
# dtype: float64
#
# Cluster 5: 24 N
# trailer react                10.205082
# react                         9.394597
# afterlife trailer             9.341460
# ghostbusters afterlife        8.122005
# afterlife                     8.101543
# trailer                       6.917133
# ghostbusters                  3.577764
# 2020 trailer                  1.037580
# afterlife 2020                0.949210
# 2020                          0.677006
# afterlife teaser              0.577587
# hordie ghostbusters           0.559115
# hordie                        0.559115
# grandfathers ghostbusters     0.449149
# grandfathers                  0.449149
# wait grandfathers             0.449149
# teaser trailer                0.431555
# teaser                        0.408108
# wait                          0.391076
# fiasco                        0.000000
# dtype: float64
#
# Cluster 6: 19 N
# 2016 movie           10.399038
# movie review          8.444349
# ghostbusters 2016     6.965110
# movie                 6.824315
# 2016                  6.317412
# review                6.118090
# ghostbusters          3.021297
# film review           0.000000
# film react            0.000000
# film reviewr          0.000000
# film rant             0.000000
# film teas             0.000000
# film parodi           0.000000
# film making           0.000000
# film loving           0.000000
# film google           0.000000
# film favorites        0.000000
# film ev               0.000000
# film clip             0.000000
# zul ghostbust         0.000000
# dtype: float64
#
# Cluster 7: 15 N
# ghostbusters movie    8.927127
# movie review          7.352429
# movie                 5.941878
# review                5.326974
# ghostbusters          2.630620
# review 2016           0.696640
# review spoil          0.566827
# spoil                 0.535919
# 2016                  0.257635
# film parodi           0.000000
# film rant             0.000000
# film loving           0.000000
# film react            0.000000
# film google           0.000000
# film favorites        0.000000
# film ev               0.000000
# film clip             0.000000
# film                  0.000000
# figures sneak         0.000000
# figures review        0.000000
# dtype: float64
#
# Cluster 8: 97 N
# ghostbusters 2016    18.455316
# 2016                 18.022400
# ghostbusters          8.571852
# review                6.901918
# 2016 trailer          4.244019
# movie                 3.868666
# 2016 movie            3.420428
# trailer               3.303791
# movie review          3.035059
# reaction              2.999976
# 2016 reaction         2.477982
# reaction review       2.006230
# trailer 2016          1.777559
# 2016 film             1.466462
# reacts                1.373894
# social justice        1.373100
# justice               1.373100
# 2016 social           1.373100
# social                1.373100
# cancer part           1.373100
# dtype: float64
#
# Cluster 9: 16 N
# 2016 review                  8.507152
# ghostbusters 2016            5.292802
# 2016                         4.800615
# review                       4.649150
# ghostbusters                 2.295890
# talk                         0.792977
# announcement ghostbusters    0.607902
# review votesaxon07           0.588023
# votesaxon07                  0.588023
# projector                    0.588023
# afterthought                 0.588023
# projector ghostbusters       0.588023
# afterthought ghostbusters    0.588023
# review spoil                 0.570673
# announcement                 0.548444
# spoil                        0.539555
# talk ghostbusters            0.531652
# movie talk                   0.501234
# spoiler talk                 0.494330
# review spoiler               0.466047
# dtype: float64
#
# 2 vid_des
#
# 1.Reading Corpus
# 2.Fit Transform TF-IDF
# 3.Create Dataframe
# 4.Fit Transform PCA
# 5.Fit Transform KMeans
# 6.Write Data
# 7.Print Summary
# vid_des_cluster
# Cluster 0: 62 N
# review                 5.922474
# 2016                   4.002427
# ghostbusters 2016      3.344732
# ghostbusters           3.147854
# movie review           2.665454
# movie                  2.576706
# reboot                 1.924391
# trailer                1.873133
# review ghostbusters    1.796522
# new                    0.995370
# spoiler                0.913242
# ghostbusters movie     0.905961
# 2016 reboot            0.881680
# die                    0.871889
# beyond                 0.867542
# reaction               0.836075
# trailer review         0.823011
# review new             0.810131
# music                  0.795039
# reviews                0.773414
# dtype: float64
#
# Cluster 1: 7 N
# apple music             1.582032
# vevo                    1.582032
# spotify apple           1.582032
# apple                   1.520104
# spotify                 1.426724
# official                1.414507
# 5sos                    1.065448
# hereitunes              1.001144
# hereitunes spotify      1.001144
# music                   0.932788
# listen                  0.815675
# yt official             0.791016
# channelsyt              0.791016
# weare5sosig tw          0.791016
# snapchat weare5sosig    0.791016
# official 5sos           0.791016
# music google            0.791016
# google play             0.791016
# listen albums           0.791016
# weare5sosig             0.791016
# dtype: float64
#
# Cluster 2: 19 N
# melissa             2.183194
# melissa mccarthy    2.057952
# mccarthy            2.045757
# wiig                1.970342
# mckinnon            1.779990
# kristen wiig        1.766538
# kate                1.763254
# kate mckinnon       1.740541
# kristen             1.723040
# leslie jones        1.708613
# leslie              1.698487
# jones               1.669498
# mckinnon leslie     1.515688
# feig                1.392567
# paul feig           1.271794
# wiig kate           1.103419
# paul                1.076257
# directed paul       1.074186
# mccarthy kristen    1.012853
# wiig melissa        0.922255
# dtype: float64
#
# Cluster 3: 89 N
# trailer                   8.686664
# ghostbusters              5.732028
# afterlife                 5.623433
# ghostbusters afterlife    5.541647
# reaction                  3.955455
# official                  3.321807
# official trailer          3.128394
# movie                     3.117603
# 2020                      2.886446
# trailer ghostbusters      2.730280
# afterlife trailer         2.597516
# new                       2.595897
# first                     2.539154
# ghostbustersafterlife     2.177032
# trailers                  2.176303
# trailer reaction          1.917738
# teaser trailer            1.827578
# trailer new               1.813273
# ghostbusters3             1.794071
# teaser                    1.694587
# dtype: float64
#
# Cluster 4: 22 N
# use                     5.036178
# fair                    3.695995
# fair use                3.494451
# disclaimer              1.529239
# news reporting          1.481296
# reporting               1.468933
# purposes criticism      1.444956
# purposes                1.429482
# section                 1.410962
# research fair           1.408533
# scholarship             1.395179
# allowance               1.395179
# teaching scholarship    1.395179
# use use                 1.395179
# allowance made          1.395179
# criticism               1.392918
# 107 act                 1.370132
# made fair               1.370132
# reporting teaching      1.370132
# use purposes            1.370132
# dtype: float64
#
# Cluster 5: 6 N
# microphone                      1.014033
# ghostbusters                    0.862246
# links                           0.851962
# ghostbusters 2020               0.826459
# ghostbusters afterlife          0.706539
# afterlife                       0.693656
# videos                          0.685544
# support                         0.682244
# 2020                            0.646984
# trailer                         0.594729
# computer business               0.549596
# one product                     0.549596
# ill receive                     0.549596
# lights computer                 0.549596
# videos camera                   0.549596
# 3cfilmreviewgmailcom            0.549596
# 3cfilmreviewgmailcom support    0.549596
# product links                   0.549596
# receive small                   0.549596
# camera microphone               0.549596
# dtype: float64
#
# Cluster 6: 18 N
# reitman                   3.759659
# jason                     2.794240
# jason reitman             2.456669
# original ghostbusters     1.862666
# gil kenan                 1.776779
# gil                       1.776779
# kenan                     1.776779
# afterlife                 1.759023
# written                   1.750656
# ghostbusters              1.701165
# ivan reitman              1.685985
# original                  1.646684
# ivan                      1.630456
# ghostbusters afterlife    1.500105
# film written              1.395357
# left behind               1.297696
# kids arrive               1.297696
# two kids                  1.297696
# ghostbusters secret       1.297696
# town begin                1.297696
# dtype: float64
#
# Cluster 7: 6 N
# collider               1.431810
# television breaking    0.646113
# news incisive          0.646113
# videos essential       0.646113
# collider videos        0.646113
# incisive               0.646113
# online source          0.646113
# source movies          0.646113
# incisive content       0.646113
# content imminent       0.646113
# essential              0.646113
# trends collider        0.646113
# trends                 0.646113
# imminent               0.646113
# imminent trends        0.646113
# television             0.631324
# movies television      0.631324
# breaking news          0.631324
# breaking               0.606611
# schmoes youtube        0.570022
# dtype: float64
#
# Cluster 8: 644 N
# ghostbusters          16.410086
# movie                 13.414635
# new                    9.579302
# film                   7.572928
# new ghostbusters       5.322873
# ghostbusters movie     5.249914
# one                    5.135961
# movies                 4.909215
# trailer                4.627387
# song                   4.385264
# review                 4.306846
# get                    4.139337
# 1984                   4.092607
# see                    4.010692
# make                   4.005306
# original               3.886088
# hope                   3.678754
# music                  3.619050
# dont                   3.544105
# find                   3.444451
# dtype: float64
#
# Cluster 9: 6 N
# chris hemsworth     0.673357
# hemsworth           0.666973
# wiig kate           0.615501
# world               0.615129
# mccarthy kristen    0.609454
# chris               0.598699
# mckinnon leslie     0.592839
# paul feig           0.583957
# feig                0.577117
# years               0.569141
# kristen wiig        0.541882
# kate mckinnon       0.538415
# mckinnon            0.535039
# wiig                0.531748
# kate                0.528539
# leslie jones        0.528539
# kristen             0.528539
# melissa mccarthy    0.528539
# leslie              0.525407
# mccarthy            0.525407
# dtype: float64

# %%
# removing records from irrelevant clusters
descriptions_cycle_2 = descriptions_cycle_2[descriptions_cycle_2.loc[:,'tag_cluster'] != 8][descriptions_cycle_2.loc[:,'vid_des_cluster'] != 1]
len(descriptions_cycle_2)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 835

# %% [markdown]
# ## 3.8 **AFTER 2 CYCLES** Training Classification Models

# %% [markdown]
# #preparing data for classification training
# data = descriptions_cycle_1.loc[:,'text'].apply(lambda x: normalize(x))
#
# #preparing label for classification training
# descriptions_cycle_1.loc[:,'label'] = descriptions_cycle_1.loc[:,'vid_id'].apply(lambda x: 1 if x in list(descriptions_cycle_2.vid_id) else 0)
# labels = descriptions_cycle_1['label']
# indices = descriptions_cycle_1.index.values
#
# #splitting train/test
# X_train, X_test,indices_train,indices_test = train_test_split(np.array(data),indices, test_size=0.33, random_state=42)
# y_train, y_test = labels[indices_train],  labels[indices_test]

# %%
#tfidf transformation
tv = TfidfVectorizer(tokenizer=word_tokenize, stop_words=stop_words, 
                     preprocessor=stemmer.stem, 
                     ngram_range=(1,2))
train_features = tv.fit_transform(X_train)
test_features = tv.transform(X_test)

# %%
#fiting and predicting with a Support Vector Machine classifier
svm = LinearSVC(penalty='l2', C=1, random_state=42) 
svm.fit(train_features, y_train)
svm_tfidf_test_score = svm.score(test_features, y_test) 
print('Test Accuracy:', svm_tfidf_test_score)
y_pred_svm = svm.predict(test_features)
# Out:
# Test Accuracy: 0.803030303030303

# %%
skplt.metrics.plot_confusion_matrix(y_test, y_pred_svm)

# %%
#tuning a random forest classifier
estimators = [5,10,15,20,25]
for e in estimators:
    rfc = RandomForestClassifier(n_estimators=e, random_state=42)
    rfc.fit(train_features, y_train)
    rfc_tfidf_test_score = rfc.score(test_features, y_test) 
    print('Test Accuracy:'+ str(e) + ' ' + str(rfc_tfidf_test_score))
# Out:
# Test Accuracy:5 0.8042929292929293
# Test Accuracy:10 0.8194444444444444
# Test Accuracy:15 0.8320707070707071
# Test Accuracy:20 0.8257575757575758
# Test Accuracy:25 0.8371212121212122

# %%
skplt.metrics.plot_confusion_matrix(y_test, y_pred_rfc)

# %% [markdown]
# ## 3.9 Manually Reviewing False Positives/Negatives

# %%
# joining the rfc prediction back to the original dataframe
descriptions_cycle_1.loc[indices_test,'rfc_pred_test'] = y_pred_rfc
descriptions_cycle_1.loc[indices_train,'rfc_pred_test'] = y_train
descriptions_cycle_1.loc[:,'rfc_pred_test'] = descriptions_cycle_1.loc[:,'rfc_pred_test'].astype(np.int64)
descriptions_cycle_1[descriptions_cycle_1.loc[:,'label'] == 0][descriptions_cycle_1.loc[:,'rfc_pred_test'] == 1].to_csv('false_positive.csv')

# %%
# importing reviewed false positives dataframe =
reviewed_false_positive = pd.read_csv('false_positive.csv')

# %%
reviewed_false_positive.head()
# Out:
#                                  vid_id
# 0  5e6fe247-a52e-467b-acd7-240bd254f6e9
# 1  5954f1dd-9ff2-42df-bcfe-07621da2b1db
# 2  5e6fe233-a02b-43ce-8ff2-3c9c0b36d979
# 3  5e62e70b-3558-455b-bd8f-7c6cb22ca6e2
# 4  5e62e70c-2902-492d-bcd2-172705102471

# %%
# joining the wrong false positives to the dataframe to get a more comprehensive set of matches
descriptions_cycle_1.loc[:,'final_label'] = descriptions_cycle_1.loc[:,'label'] + descriptions_cycle_1.loc[:,'vid_id'].apply(lambda x: 1 if x in list(reviewed_false_positive.vid_id) else 0).astype(np.int64)

# %%
descriptions_cycle_1.groupby('final_label').count()
# Out:
#              vid_id  vid_title   tag  vid_des  post_date  owner_id  com_num  \
# final_label
# 0              1530       1530  1530     1530       1530      1530     1484
# 1               867        867   867      867        867       867      763
#
#              like_num  dis_num  text  title_des_text  text_tokens  \
# final_label
# 0                1473     1473  1530            1530         1530
# 1                 762      762   867             867          867
#
#              title_des_tokens  first_tag_ghostbuster  \
# final_label
# 0                        1530                   1530
# 1                         867                    867
#
#              first_tag_ghostbuster_title_des  tag_cluster  vid_title_cluster  \
# final_label
# 0                                       1530         1530               1530
# 1                                        867          867                867
#
#              vid_des_cluster  label  rfc_pred_test
# final_label
# 0                       1530   1530           1530
# 1                        867    867            867

# %% [markdown]
# ## 3.10 Looking into Video Matches

# %%
# creating the final video match dataframe
descriptions_final = descriptions_cycle_1[descriptions_cycle_1.loc[:,'final_label']==1]
descriptions_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 867 entries, 46 to 38503
# Data columns (total 21 columns):
# vid_id                             867 non-null object
# vid_title                          867 non-null object
# tag                                867 non-null object
# vid_des                            867 non-null object
# post_date                          867 non-null datetime64[ns, UTC]
# owner_id                           867 non-null object
# com_num                            763 non-null float64
# like_num                           762 non-null float64
# dis_num                            762 non-null float64
# text                               867 non-null object
# title_des_text                     867 non-null object
# text_tokens                        867 non-null object
# title_des_tokens                   867 non-null object
# first_tag_ghostbuster              867 non-null float64
# first_tag_ghostbuster_title_des    867 non-null float64
# tag_cluster                        867 non-null int32
# vid_title_cluster                  867 non-null int32
# vid_des_cluster                    867 non-null int32
# label                              867 non-null int64
# rfc_pred_test                      867 non-null int64
# final_label                        867 non-null int64
# dtypes: datetime64[ns, UTC](1), float64(5), int32(3), int64(3), object(9)
# memory usage: 138.9+ KB

# %%
descriptions_final.to_csv('descriptions_final')

# %%
# checking unique count of each column
print(descriptions_final.nunique())
print(descriptions_final.groupby('owner_id').nunique()[['vid_id']].sort_values(by=['vid_id'], ascending=False).head())
# Out:
# Unnamed: 0                         867
# vid_id                             867
# vid_title                          839
# tag                                711
# vid_des                            864
# post_date                          867
# owner_id                           684
# com_num                            275
# like_num                           383
# dis_num                            194
# text                               867
# title_des_text                     867
# text_tokens                        867
# title_des_tokens                   867
# first_tag_ghostbuster              3
# first_tag_ghostbuster_title_des    4
# tag_cluster                        4
# vid_title_cluster                  8
# vid_des_cluster                    5
# label                              2
# rfc_pred_test                      2
# final_label                        1
# year                               14
# dtype: int64
#                                       vid_id
# owner_id
# 5beb1d86-e940-4e7e-b9f9-fc46229203b1  8
# 5beb1d8e-b2e0-4b13-8986-f350238769ec  7
# 5bed24ae-02e0-4e22-a166-7604496090ad  6
# 5beb1491-f2bc-4b43-91df-44777cfbe800  6
# 58e5286e-57eb-4c7a-a6bf-47d51526c8b4  5

# %%
# most productive content creator's content
descriptions_final[descriptions_final['owner_id'] == '5beb1d86-e940-4e7e-b9f9-fc46229203b1'][['vid_title','like_num','com_num','dis_num','post_date']]
# Out:
#                                                                                             vid_title  \
# 100  Jennifer Lawrence & Amy Schumer best friends! Ghostbusters Remake vs Remake - Beyond The Trailer
# 469  Ghostbusters 2016 First Look, On-Set Photos - Review aka Reaction - Beyond The Trailer
# 560  Ghostbusters 2016 Movie Review
# 645  Box Office for The Secret Life of Pets, Ghostbusters 2016 Reviews, Sultan
# 649  Ghostbusters 2016 SPOILERS Movie Review
# 665  Top Ten Worst Movies of 2016
# 790  Ghostbusters 2016 Trailer 2 REACTION
# 816  Ghostbusters Afterlife Trailer REACTION
#
#      like_num  com_num  dis_num                  post_date
# 100  302.0     34.0     16.0     2015-07-31 14:08:02+00:00
# 469  764.0     623.0    720.0    2015-06-22 17:01:26+00:00
# 560  2088.0    1189.0   2721.0   2016-07-10 16:45:15+00:00
# 645  940.0     480.0    139.0    2016-07-11 19:51:20+00:00
# 649  1153.0    611.0    1111.0   2016-07-10 18:02:24+00:00
# 665  2110.0    1117.0   306.0    2017-01-05 17:03:05+00:00
# 790  2753.0    2300.0   1052.0   2016-05-18 14:38:27+00:00
# 816  5317.0    1218.0   615.0    2019-12-09 14:57:46+00:00

# %%
# video count by year
descriptions_final['year'] = pd.DatetimeIndex(descriptions_final['post_date']).year
descriptions_final.groupby('year').nunique()['vid_id'].reset_index().rename(columns={'vid_id':'vid_count'}).plot.bar(x='year', y='vid_count',colormap='summer', rot=50)

# %% [markdown]
# # 4. Looking For Ghostbusters Related Comments

# %% [markdown]
# ## 4.1 Cleaning and Filtering Comments Dataset

# %%
comments.head()
# Out:
#                              Comment ID                              Video ID  \
# 0  5d49a4e8-0632-4132-b1f2-163615d73515  5d49a262-27e5-4e39-831f-ad1b59e13bf9
# 1  5d49a4e9-6397-4bdb-b63d-d5a963881ac8  5d49a261-5474-43a8-8cb5-18d51f0d7398
# 2  5d49a4e9-485e-4761-8acf-7e5128e3f9ae  5d49a261-5474-43a8-8cb5-18d51f0d7398
# 3  5d49a4e9-ae09-4be3-a181-487583f22cf0  5d49a261-5474-43a8-8cb5-18d51f0d7398
# 4  5d49a4e9-d129-420e-b046-895fc962ec20  5d49a261-5474-43a8-8cb5-18d51f0d7398
#
#                                              Comment  \
# 0                                     Absolute human
# 1                                      good job guys
# 2  Yikes <a href="https://chrome.google.com/webst...
# 3  I first stumbled across Coheed back during fre...
# 4  saw them last year and it was one of the best ...
#
#                                                age  \
# 0  {'value': 'young', 'score': 0.5281285668295823}
# 1  {'value': 'young', 'score': 0.7313715408212422}
# 2                 {'value': 'young', 'score': 0.5}
# 3                   {'value': 'mid', 'score': 0.5}
# 4   {'value': 'young', 'score': 0.886839130276653}
#
#                                gender  \
# 0     {'value': 'male', 'score': 1.0}
# 1     {'value': 'male', 'score': 1.0}
# 2  {'value': 'unknown', 'score': 1.0}
# 3  {'value': 'unknown', 'score': 1.0}
# 4     {'value': 'male', 'score': 1.0}
#
#                                            ethnicity
# 0                   {'value': 'white', 'score': 1.0}
# 1                   {'value': 'white', 'score': 1.0}
# 2                   {'value': 'asian', 'score': 1.0}
# 3  {'value': 'african_black', 'score': 0.98591950...
# 4                 {'value': 'unknown', 'score': 1.0}

# %%
# changing comments column names
comments = comments.rename({'Video ID': 'vid_id', 
                            'Comment ID': 'com_id',
                            'Comment':'com'}, axis=1)

# %%
# removing all comments from videos that are not related to ghostbusters
# %%time
comments['relevance'] = comments['vid_id'].apply(lambda x: 1 if x in list(descriptions_final.vid_id) else 0)
# Out:
# CPU times: user 37.1 s, sys: 8.71 ms, total: 37.1 s
# Wall time: 37.1 s

# %%
relevant_comment = comments[comments['relevance'] == 1]

# %%
relevant_comment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72447 entries, 14 to 461778
# Data columns (total 7 columns):
# com_id       72447 non-null object
# vid_id       72447 non-null object
# com          72446 non-null object
# age          72447 non-null object
# gender       72447 non-null object
# ethnicity    72447 non-null object
# relevance    72447 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 4.4+ MB

# %%
# exporting relevant comment to csv dataset for the next working session
relevant_comment.to_csv('relevant_comment.csv')
relevant_comment = pd.read_csv('relevant_comment.csv')

# %% [markdown]
# ## 4.2 Preprocessing Comments

# %%
# Tailoring normalizing function for comments 
def normalize_comment(s):
    s = str(s)
    stripped = re.sub('http://\S+|https://\S+', '', s)
    stripped = re.sub(r'[^a-zA-z\s]' , '', stripped)
    stripped = re.sub('\n','',stripped)
    stripped = re.sub('_','',stripped)
    stripped = re.sub('-','',stripped)
    stripped = stripped.lower()
    stripped = stripped.strip("[]")
    stripped = expand_contractions(stripped)
    return stripped

# %%
# Clustering comments to get an intial understanding of the corpus
# %%time
output_cols = []
n_clusters = 8
n_pca_groups = 50

print("1.Reading Corpus")
corpus = list(relevant_comment.loc[:,'com'].apply(lambda x: normalize_comment(x)))
vectorizer = TfidfVectorizer(tokenizer=word_tokenize, stop_words=stop_words, 
                                 preprocessor=stemmer.stem, 
                                 ngram_range=(1,3),
                                 max_features = 500)
print("2.Fit Transform TF-IDF")
X = vectorizer.fit_transform(corpus)
tfidf_cols = list(vectorizer.get_feature_names())
print("3.Create Dataframe")
tfidf_df = pd.DataFrame(data=X.todense(), columns=vectorizer.get_feature_names())
    
#pca = PCA(n_components=n_pca_groups)
#print("4.Fit Transform PCA")
#pca_df = pca.fit_transform(tfidf_df)
#pca_df = pd.DataFrame(data=pca_df)
    
print("5.Fit Transform KMeans")
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(tfidf_df)
pred = kmeans.predict(tfidf_df)
cluster_col_name = '{}_cluster'.format('com')

print("6.Write Data")
tfidf_df[cluster_col_name] = pred
relevant_comment[cluster_col_name] = pred
    
output_cols.append(cluster_col_name)
print("7.Print Summary")
print(cluster_col_name)
for x in np.unique(pred):
    temp = tfidf_df[tfidf_df[cluster_col_name]==x][tfidf_cols].sum()
    temp = temp.sort_values(ascending=False)
    print('Cluster {x}: {n} N'.format(x=x, n='{:,}'.format(np.sum(relevant_comment[cluster_col_name]==x))))
    print(temp[:20])
    print()
# Out:
# 1.Reading Corpus
# 2.Fit Transform TF-IDF
# 3.Create Dataframe
# 5.Fit Transform KMeans
# 6.Write Data
# 7.Print Summary
# com_cluster
# Cluster 0: 1,123 N
# thought         444.980559
# movie            51.398749
# good             40.732462
# trailer          33.699081
# one              29.323147
# really           27.829861
# first            26.932314
# didnt            26.367561
# ghostbusters     26.342526
# br               26.104384
# actually         25.182100
# im               25.068261
# bad              24.596593
# saw              23.911779
# film             23.734491
# funny            23.619030
# going            22.504623
# looked           21.546366
# dont             19.444792
# see              19.407224
# dtype: float64
#
# Cluster 1: 1 N
# really                   0.371341
# looking                  0.342338
# roles                    0.199505
# racist                   0.194002
# top                      0.191252
# job                      0.183465
# comes                    0.182525
# bill murray              0.180151
# mccarthy                 0.179811
# humor                    0.179698
# girl                     0.176095
# original ghostbusters    0.175896
# murray                   0.173100
# cool                     0.170372
# hard                     0.168680
# bill                     0.165768
# work                     0.165697
# trying                   0.160157
# point                    0.157142
# oh                       0.156875
# dtype: float64
#
# Cluster 2: 1,578 N
# href            1140.235039
# br                52.305030
# lol               27.044720
# ghostbusters      21.090252
# movie             16.465676
# thats             16.141271
# mike              15.664581
# best              13.602270
# right             13.351374
# man               12.281284
# part              12.264265
# oh                11.817429
# ghost             11.772534
# love              11.380375
# see               11.315580
# want              11.021446
# reaction          10.911337
# xd                10.820475
# laugh             10.786854
# im                10.278106
# dtype: float64
#
# Cluster 3: 55,063 N
# br              1472.504358
# ghostbusters    1389.379609
# im              1018.008394
# one              919.361636
# dont             911.209695
# looks            900.288781
# good             875.375901
# lol              794.359942
# film             791.587981
# think            738.418561
# love             713.287629
# see              702.898047
# shit             695.120946
# trailer          690.793504
# thats            660.090602
# people           647.453414
# get              625.029016
# man              621.618457
# original         596.572921
# know             592.224977
# dtype: float64
#
# Cluster 4: 10,480 N
# movie           2542.327253
# br               450.649509
# ghostbusters     385.082633
# people           347.115894
# good             336.018961
# dont             332.766247
# see              311.706393
# original         297.327720
# im               285.007469
# trailer          280.384786
# bad              276.478912
# one              264.431718
# think            257.462176
# going            237.444781
# really           232.661199
# even             232.182562
# shit             223.293111
# didnt            208.833908
# women            206.843035
# looks            206.727618
# dtype: float64
#
# Cluster 5: 1,292 N
# look            502.836722
# doesnt           68.840637
# good             50.221851
# trailer          50.215163
# movie            40.933954
# dont             35.158273
# ghosts           33.865508
# looks            33.694418
# bad              32.863908
# br               29.153399
# original         28.432917
# funny            26.571053
# ghostbusters     26.412902
# ghost            25.269928
# one              24.496990
# think            24.277417
# really           23.921532
# make             22.864514
# made             22.635433
# see              21.936357
# dtype: float64
#
# Cluster 6: 1,368 N
# review          655.928031
# movie            64.668052
# great            51.695206
# chris            49.007976
# good             37.948056
# film             29.066675
# see              28.851830
# honest           27.096600
# ghostbusters     27.091556
# br               24.500861
# im               21.280743
# really           21.119864
# man              20.890866
# seen             20.563862
# movi             19.860894
# fair             19.231412
# give             19.219922
# angry            19.190909
# think            19.032731
# reviews          18.693899
# dtype: float64
#
# Cluster 7: 1,542 N
# movi            765.617928
# ghostbusters     47.937940
# movie            37.984792
# good             37.482605
# see              29.674671
# im               29.300246
# love             28.848976
# bad              23.781591
# looks            23.341522
# trailer          22.961455
# people           22.857783
# better           22.830840
# dont             22.802443
# one              22.224897
# new              21.984360
# shit             21.917145
# really           21.863299
# original         21.158800
# fuck             20.127598
# cant             20.007494
# dtype: float64
#
# CPU times: user 1min 14s, sys: 9.94 s, total: 1min 24s
# Wall time: 1min 19s

# %%
# Updating stop word list to comment content
stop_words_2 = set(stopwords.words('english'))
extra_words_2 = ['gtgtgtgtghostbust','ive','gt','lt','yay','gtgtgtgtghostbusters','','fuck','fucking','first','even','xd','im','br','href','lol','one','href','still','isnt','dont',"[","]",'copyright','1','2','3','4','5','us','tumblr','patreon','twitter', 'facebook', 'creepypasta', 'instagram', 'like', 'video','subscribe', 'please', 'channel', 'comment', 'forget',  'check',   'thanks',  'guys',    'enjoy',   'share',   'follow', 'plea', 'watching', "'", "'d", "'ll", 'abov', 'ani', 'becaus', 'befor', 'could', 'doe', 'dure', 'ha', 'hi', 'might', 'must', "n't", 'need', 'onc', 'onli', 'ourselv', 'r', 'sha', 'themselv', 'thi', 'v', 'veri', 'wa', 'whi', 'wo', 'would', 'yourselv','becau', 'guy', 'pleas', 'subscrib', 'thank', 'watch']
for w in extra_words_2:
    stop_words_2.add(w)

# %%
# Preprocessing comments
# %%time
relevant_comment['comment_tokens'] = relevant_comment.loc[:,'com'].apply(lambda x: preprocess(x))
# Out:
# CPU times: user 25.5 s, sys: 45.4 ms, total: 25.6 s
# Wall time: 25.6 s

# %% [markdown]
# ## 4.3 Creating a Comment Matcher

# %%
# Comment matcher similar to Video's with more relevant words extracted from the clustering results
def ghost_buster_related_comment(list):
    label = 0
    if process.extractOne("ghostbuster", list, score_cutoff = 91) != None:
        label += 1
    important_words = ['plot','think','direct','movie','movies','film','films','afterlife','review','trailer']
    for w in important_words:
        if process.extractOne(w, list, score_cutoff = 100) != None:
            label += 0.25
    punished_words = {'halloween':80,'dimensions':95,'paranormal':90,'haunted':92,'game':89,'pokemon':100,'toy':86,'ecto1':100,'ecto':100,'lego':85,'wellness':85,'comic':100,'book':100}
    for key, value in punished_words.items():
        if process.extractOne(key, list, score_cutoff = value) != None:
            label -= 5
    return label

# %%
# matching comments against the matcher
# %%time
relevant_comment['related_tag'] =  relevant_comment.loc[:,'comment_tokens'].apply(lambda x: ghost_buster_related_comment(x))
# Out:
# CPU times: user 10min 42s, sys: 88.8 ms, total: 10min 42s
# Wall time: 10min 42s

# %%
# Extracting comments related to Ghostbusters
relevant_comment = relevant_comment[relevant_comment.related_tag >= 1]

# %% [markdown]
# ## 4.3 Euclidean Similarity of Comments to Video Corpus

# %%
# making a corpus of video title and description texts
corpus = set(list(result.loc[:,'title_des_text'].apply(lambda x: normalize(x))))
one_corpus = ' '.join(corpus)

# initiating a vectorizer
vectorizer = TfidfVectorizer(tokenizer=word_tokenize, stop_words=stop_words, 
                                 preprocessor=stemmer.stem, 
                                 ngram_range=(1,2),
                                 max_features = 1000)
tfidf_vector = vectorizer.fit_transform([one_corpus])

#creating the euclidean similarity function
def euclidean_similarity(tfidf_vector,x):
    nom = normalize(x)
    x_vec = vectorizer.transform([nom])
    sim = euclidean_distances(tfidf_vector,x_vec)
    sim_score = sim.sum()
    return sim_score

# %%
# finding euclidean similarity score
relevant_comment['sim_score'] = relevant_comment['com'].apply(lambda x: euclidean_similarity(tfidf_vector,x))

# %%
print(relevant_comment.vid_id.nunique())
print(relevant_comment.shape)
# Out:
# 180
# (6694, 11)

# %%
# finding passionate ghostbusters comments
ghostbuster_comment = relevant_comment[relevant_comment['sim_score'] < 1]
print(ghostbuster_comment.vid_id.nunique())
print(ghostbuster_comment.shape)
# Out:
# 101
# (826, 15)

# %%
# reclustering for a better idea of passionate comments
# %%time
output_cols = []
n_clusters = 10
n_pca_groups = 50

print("1.Reading Corpus")
corpus = list(ghostbuster_comment.loc[:,'com'].apply(lambda x: normalize_comment(x)))
vectorizer = TfidfVectorizer(tokenizer=word_tokenize, stop_words=stop_words_2, 
                                 preprocessor=stemmer.stem, 
                                 ngram_range=(1,1),
                                 max_features = 1000)
print("2.Fit Transform TF-IDF")
X = vectorizer.fit_transform(corpus)
tfidf_cols = list(vectorizer.get_feature_names())
print("3.Create Dataframe")
tfidf_df = pd.DataFrame(data=X.todense(), columns=vectorizer.get_feature_names())
    
pca = PCA(n_components=n_pca_groups)
print("4.Fit Transform PCA")
pca_df = pca.fit_transform(tfidf_df)
pca_df = pd.DataFrame(data=pca_df)
    
print("5.Fit Transform KMeans")
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(pca_df)
pred = kmeans.predict(pca_df)
cluster_col_name = '{}_cluster'.format('com')

print("6.Write Data")
tfidf_df[cluster_col_name] = pred
ghostbuster_comment[cluster_col_name] = pred
    
output_cols.append(cluster_col_name)
print("7.Print Summary")
print(cluster_col_name)
for x in np.unique(pred):
    temp = tfidf_df[tfidf_df[cluster_col_name]==x][tfidf_cols].sum()
    temp = temp.sort_values(ascending=False)
    print('Cluster {x}: {n} N'.format(x=x, n='{:,}'.format(np.sum(ghostbuster_comment[cluster_col_name]==x))))
    print(temp[:10])
    print()
# Out:
# 1.Reading Corpus
# 2.Fit Transform TF-IDF
# 3.Create Dataframe
# 4.Fit Transform PCA
# 5.Fit Transform KMeans
# 6.Write Data
# 7.Print Summary
# com_cluster
# Cluster 0: 44 N
# afterlife       13.855345
# afterlif        8.259002
# ghostbusters    7.807601
# got             2.995044
# sounds          1.269544
# ghostbust       0.981266
# wonder          0.964026
# origin          0.937526
# remake          0.930966
# trail           0.929844
# dtype: float64
#
# Cluster 1: 90 N
# ghostbusters    89.337147
# ghostbust       0.717671
# babe            0.643022
# way             0.419455
# zuul            0.000000
# franchise       0.000000
# future          0.000000
# futur           0.000000
# funny           0.000000
# funnier         0.000000
# dtype: float64
#
# Cluster 2: 8 N
# suck            5.283795
# ghostbusters    0.957109
# fact            0.701377
# get             0.676436
# shoo            0.629220
# bett            0.594931
# troll           0.592902
# cast            0.543703
# billl           0.515700
# expected        0.488540
# dtype: float64
#
# Cluster 3: 10 N
# liked           8.745151
# ghostbusters    1.690326
# critics         0.625336
# seen            0.560502
# trailer         0.547972
# fan             0.506260
# never           0.505787
# lot             0.305283
# movie           0.281322
# much            0.277035
# dtype: float64
#
# Cluster 4: 98 N
# movie           22.571313
# ghostbusters    11.343409
# original        3.078008
# movies          2.631884
# made            2.595729
# good            2.558019
# new             2.199486
# shit            2.147402
# real            1.972696
# also            1.769968
# dtype: float64
#
# Cluster 5: 439 N
# ghostbusters    59.803528
# shit            9.046595
# feminist        7.496961
# edit            6.394357
# original        5.830637
# girl            4.823066
# amp             4.720940
# new             4.496342
# movies          4.481141
# mean            4.454224
# dtype: float64
#
# Cluster 6: 33 N
# better          11.227878
# ghostbusters    5.554619
# way             2.765370
# movie           2.156202
# chris           1.809171
# said            1.447869
# stuckmann       1.076790
# great           1.056884
# thinks          1.048295
# think           1.016246
# dtype: float64
#
# Cluster 7: 11 N
# cool            9.162010
# ghostbusters    1.940252
# sketch          0.660512
# troll           0.639305
# liking          0.611520
# snl             0.575963
# bothered        0.572342
# couldnt         0.547467
# women           0.445552
# follows         0.000000
# dtype: float64
#
# Cluster 8: 29 N
# movi            13.648236
# ghostbusters    3.954603
# movie           1.968250
# horror          1.638082
# real            1.202779
# extreme         1.161838
# excuse          1.085496
# honestly        0.847182
# hillary         0.847182
# course          0.836283
# dtype: float64
#
# Cluster 9: 64 N
# trailer         19.466214
# ghostbusters    6.496608
# reaction        3.341879
# afterlife       3.242155
# movie           2.874506
# official        2.642972
# original        1.929322
# trail           1.809405
# seen            1.654212
# love            1.587076
# dtype: float64
#
# CPU times: user 1.01 s, sys: 462 ms, total: 1.47 s
# Wall time: 1.21 s
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## 4.4 Creating a Lexicon Based Sentiment Analyzer

# %%
# try VADER lexicon 
def analyze_sentiment_vader_lexicon(com):
    n_com = normalize(com)
    analyzer = SentimentIntensityAnalyzer()
    scores = analyzer.polarity_scores(n_com)
    score = scores['compound']
    final_score = 'positive' if score > 0.5 else 'negative'
    return final_score

# %%
# computing sentiment score
relevant_comment['sentiment_score'] = relevant_comment['com'].apply(lambda x: analyze_sentiment_vader_lexicon(x))
relevant_comment[['com','sentiment_score']].head(5)
# Out:
#                                                                                                                                                                                                            com  \
# 23  why did they call thr movie just ghostbusters again i mean there are ghostbusters then ghostbusters 2 and now ghostbuster no 3 nothing why? i find the old classic better
# 25  the girls ghostbusters didnt fight the stay puft marshmellow man
# 38  Ghostbuster Bike?........ Really?...........Pass
# 39  The new Scooby Doo movie looks great.... Oh wait this is a Michael Bay Ghostbusters film made for kids, because the original Ghostbusters was for kids right?<br />Was hoping to not see another cash grab
# 43  but seiously I am not a sexist but I hate ghostbusterts 2016
#
#    sentiment_score
# 23  negative
# 25  negative
# 38  negative
# 39  positive
# 43  positive

# %%
# Looks like lexicon based Sentiment Analyzer doesn't work so well in this case
relevant_comment[['com','sentiment_score']].loc[43,'com']
# Out:
# 'but seiously I am not a sexist but I hate ghostbusterts 2016'

# %% [markdown]
# # 5. Visualizations

# %%
# Creating a video title and description corpus
video_corpus = preprocess(one_corpus)

# %%
# Vectorizing the corpus
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(
                     tokenizer=word_tokenize, 
                     stop_words=stop_words_2, 
                     preprocessor=stemmer.stem, 
                     ngram_range=(1,2)
                     ) 
cv_features = cv.fit_transform(video_corpus)
cv_features.shape
# Out:
# (10726, 2735)

# %%
vocabulary = np.array(cv.get_feature_names()) 
print('Total Vocabulary Size:', len(vocabulary))
# Out:
# Total Vocabulary Size: 2735

# %%
# trying LDA topic modeling
# %%time
lda_model = LatentDirichletAllocation(n_components = 20, 
                                      max_iter=500, 
                                      max_doc_update_iter=50, 
                                      learning_method='online', 
                                      batch_size=1740, 
                                      learning_offset=50., 
                                      random_state=42, 
                                      n_jobs=16) 
document_topics = lda_model.fit_transform(cv_features)
# Out:
# CPU times: user 45.6 s, sys: 13.2 s, total: 58.8 s
# Wall time: 5min 48s

# %%
# Inserting topic terms to a dataframe
topic_terms = lda_model.components_
top_terms = 10
topic_key_term_idxs = np.argsort(-np.absolute(topic_terms), axis=1)[:,:top_terms]
topic_keyterms = vocabulary[topic_key_term_idxs]
topics = [', '.join(topic) for topic in topic_keyterms] 
pd.set_option('display.max_colwidth', -1)
topics_df = pd.DataFrame(topics,
columns = ['Terms per Topic'], index=['Topic'+str(t) for t in range(1,20+1)])

# %%
topics_df
# Out:
#                                                                                      Terms per Topic
# Topic1   support, social, merch, footag, finn, behind, research, pro, light, michael
# Topic2   paul, ghostbustersafterlif, want, hd, know, ever, begin, trailerreact, mom, becom
# Topic3   review, film, product, cast, today, town, male, gain, affili, locat
# Topic4   ghostbust, ross, let, lesli, grandfath, j, wiig, allow, gear, snapchat
# Topic5   offici, direct, jone, help, kenan, assist, pictur, mckenna, breakdown, canon
# Topic6   clip, look, critic, voic, call, much, thought, shoutout, entir, stay
# Topic7   movi, bill, visit, aykroyd, connect, titl, someth, ghostbustersafterlifetrail, mike, latest
# Topic8   music, bolling, episod, favorit, day, great, boon, univers, theme, everyon
# Topic9   pencilm, link, give, youtub, singl, produc, dan, kid, melissa, camera
# Topic10  get, reboot, fan, murray, show, feminist, go, franchis, mail, store
# Topic11  fair, rudd, florencio, donat, summer, arriv, report, marshmallow, power, littl
# Topic12  origin, reitman, anim, releas, come, react, disclaim, join, written, discov
# Topic13  media, ryan, discuss, click, year, page, life, els, interview, mayb
# Topic14  star, scene, upcom, comedi, man, torpey, week, email, po, chapter
# Topic15  new, talk, gil, may, commentari, composit, back, design, section, educ
# Topic16  use, make, ivan, twitch, made, take, everi, mccarthi, chri, ghostbusterstrail
# Topic17  see, soni, purpos, legaci, cameron, mckinnon, name, octob, shot, box
# Topic18  director, news, small, content, kate, left, adam, best, grace, york
# Topic19  jason, next, full, also, kristen, dvd, send, coon, jt, huge
# Topic20  trailer, afterlif, reaction, feig, think, two, world, live, teaser, parodi

# %%
# making word cloud for video title and description
video_corpus_trimmed = [i for i in video_corpus if i not in ['ghostbusters','ghostbuster']]
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(' '.join(video_corpus_trimmed))
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FD4F8EF6C88>

# %%
# making word cloud for comments
comment_corpus = list(ghostbuster_comment.loc[:,'com'].apply(lambda x: preprocess(x)))
comment_corpus = set(itertools.chain(*comment_corpus))
comment_corpus_trimmed = [i for i in comment_corpus if i not in ['ghostbusters','ghostbuster','cuck','shit','lot']]
wordcloud.generate(' '.join(comment_corpus))
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FD4EE75D940>

# %%
# looking into feminist related videos/comments
ghostbuster_comment[ghostbuster_comment['com_cluster'] == 4]
# Out:
#        Unnamed: 0                                com_id  \
# 3599   49573       5e701132-fa0a-4afc-a01a-d4a9bc5f6482
# 3652   49690       5e6fe7a2-9fab-46eb-af62-02f86a1509e1
# 7464   68928       5e70a704-a278-4514-a467-483d25a1f691
# 12991  87442       5e7128c3-3aa3-4561-8e61-5d10f3118654
# 15507  129438      5e6334ff-9f9f-4570-9e91-90f973ef0a82
# 16407  134934      5e63a7fa-c2e9-49f6-aa23-8b9efeb19241
# 16762  137278      5e62e804-ec33-448c-a316-780c83136bfe
# 19195  145852      5e70affc-8fc1-4e5d-9f54-7bf73762295b
# 19489  146815      5e7096d9-8c87-4f68-b85d-48b4ec413552
# 20656  150786      5e70acf3-86f6-4b77-8e29-86f726364811
# 21576  153716      5e70fe5c-d8d3-4769-b401-3c28440fdd04
# 26878  174218      5e6fe8de-7db6-4106-9f15-a07ce621103e
# 27615  178884      5e700de9-975a-43ee-8d02-8b2a5f0f85c1
# 27838  179975      5e7016d3-0198-41bc-b822-0be05aefc7cb
# 32111  234409      5e7011dc-a3ea-415d-915d-46c54fa06c58
# 33258  238917      5e701c07-4949-490b-a660-b7453a63533b
# 44772  317007      5e63d4ff-d293-4bb9-a10c-73cfe574f151
# 45183  320473      5e6438ff-0d96-4657-bfc2-57965390dcc7
# 48983  332652      5e713cb4-0a31-4c6b-9165-5c8a51c8befd
# 51369  345793      5e7028bb-5a2e-4f9f-a0c1-0a162fce4aa0
# 51666  346956      5e70297a-d021-4650-89d0-83ae49702149
# 52176  349115      5e70557f-e956-4ccb-b3a4-bf97a0cd701e
# 52378  349983      5e70487e-e205-4b78-84fb-5e2143c3ded4
# 56066  362087      5e70d618-d463-4ff4-9f05-2f13f5b4a574
# 57977  369919      5a35579e-9159-4b1d-a31c-8e1f8b2e850d
# 58197  370994      5b917165-3cdb-4ffd-8eb7-da9831e53395
# 59367  408372      5e62eb25-2eac-4cbc-91db-c49b8327f612
# 60951  417029      5e6fe873-37e2-4b34-a802-38df9d25c03d
# 62693  425685      5e700f4f-7ec4-4d91-9fce-61baabe5a515
# 69487  448929      5e711dbe-1f42-48ae-b995-fddf028df73f
# 70235  450663      5e7127f0-1221-46c4-a1e2-ff757113c7e5
#
#                                      vid_id  \
# 3599   5e6fe246-2f0d-4ca5-838c-b280b03a3c74
# 3652   5e6fe22f-ed74-4b39-9280-8b6c1b2dd3cb
# 7464   5e6fe297-7eb1-4563-889f-2529d9798f50
# 12991  5e6fe265-824d-46b3-ac20-f7faddd38b04
# 15507  5e62e70d-25a1-4e1e-960b-3f7233013b02
# 16407  5e0a3a7d-6b56-4df4-a6e2-369de55dc874
# 16762  5e62e70e-082d-4961-9c68-9a81d6fc3a76
# 19195  5e6fe246-2f0d-4ca5-838c-b280b03a3c74
# 19489  5e6fe280-0976-4c49-a7c8-4b2256cb4b75
# 20656  5e6fe298-2247-46a7-94dd-60512908814e
# 21576  5e6fe25c-ce9b-4b0a-85e4-1cbe0cf2534b
# 26878  5e6fe287-b580-4a9a-afc6-2ffe8943d430
# 27615  5e6fe22e-eb95-47dc-b561-50383270653d
# 27838  5e6fe266-c9e3-4630-8e7e-0d3b752e126a
# 32111  5e6fe249-37ff-49e9-9fdd-548d2d6c7f27
# 33258  58d86745-a95d-498c-9da1-5fa64a61ef05
# 44772  5e62e70b-c905-4d6f-a96f-9f0e3c883f6f
# 45183  5e62e70d-25a1-4e1e-960b-3f7233013b02
# 48983  5e6fe28d-e0ec-4247-857b-197099abc1e4
# 51369  5e6fe240-ff3b-4625-b536-e4b99dd701db
# 51666  5e6fe246-2f0d-4ca5-838c-b280b03a3c74
# 52176  5e6fe25c-ce9b-4b0a-85e4-1cbe0cf2534b
# 52378  5e6fe287-b580-4a9a-afc6-2ffe8943d430
# 56066  5e6fe265-8ffe-43db-b5bf-f6c7a19b824d
# 57977  58ed1178-026a-4f14-8131-cdda867e2fc9
# 58197  5a68b6b7-b334-4463-9620-a144ee893bfb
# 59367  5e62e70c-ac3e-43f4-9a4b-66dbbeeefcf9
# 60951  5e6fe26f-0800-40ac-8b04-5a7efe95f956
# 62693  58d579ec-1cac-4960-a832-1ed459efa72f
# 69487  5e6fe28d-e0ec-4247-857b-197099abc1e4
# 70235  5e6fe28d-e0ec-4247-857b-197099abc1e4
#
#                                                                                                                                                                       com  \
# 3599   I like all of the Ghostbusters movies
# 3652   This is a real Ghostbusters movie that we fans of the original should have gotten in 2016. F that 2016 Ghostbusters movie!
# 7464   Me too!!! AND OF COURSE THE GHOSTBUSTERS MOVIE!!
# 12991  Ghostbusters 1 is a 10/10. Ghostbusters 2 is a 8/10. Ghostbusters 2 gets way to much hate. It&#39;s a cool movie.
# 15507  What a shocker: a woman doesn’t like the replacement movie to an awful feminine excuse for a ghostbusters movie
# 16407  THIS IS HOW YOU DO A GHOSTBUSTERS MOVIE!!!!!!!IAM EXCITED GHOSTBUSTERS MOVIE !!!!!!!!!! A REAL GHOSTBUTERS MOVIE!!!!!
# 16762  Ghostbusters as a horror movie.
# 19195  This movie destroyed ghostbusters Franchising....<br /><br />yes...i saw the movie....a bad movie...
# 19489  @Sloth Nope. I truly like the looks of this as a movie. It seriously is just a regular Ghostbusters movie.
# 20656  They should reboot Ghostbusters again next year, and all ghostbusters should be played by Deadpool.<br /><br />Maybe Deadpool should play all roles in all movies.
# 21576  Ghostbusters 2016 is the Hillary Clinton of movies
# 26878  After watching ghostbusters in movie...
# 27615  Such a sad excuse for a ghostbusters movie.
# 27838  IMO it was an ok funny movie but it was a terrible Ghostbusters movie.
# 32111  Because Ghostbusters 2016 was a trash movie.
# 33258  I like it but honestly it could have not been a Ghostbusters movie
# 44772  How do they fail to see that feminist Ghostbusters was simply a terrible movie?
# 45183  Extreme Ghostbusters the movie.
# 48983  Complete and utter garbage...<br />They chose to make THIS piece of shit over an Extreme Ghostbusters movie!?
# 51369  Ghostbusters 2016 is a 400 million dollars disaster, what a horrible movie.
# 51666  This is not Ghostbusters and never will be. The Ghostbusters cartoon had a better story than this movie.
# 52176  If the Ghostbusters movie included Amy Pohler and Tina Fey, that would definitely be a billion dollar movie.
# 52378  cool, adam sandler is making a ghostbusters movie
# 56066  +holygrail2009 Right.... the fanbase. I forgot about those. Dude... it&#39;s a kids/family movie. You can&#39;t expect Shakespeare from a Ghostbusters movie.
# 57977  The new ghostbusters movie will be way better than the boring old ghostbusters movie!
# 58197  They fucked up the ghostbusters movie
# 59367  ghostbusters as a horror movie!
# 60951  Who is looking forward to seeing the Ghostbusters Afterlife movie?
# 62693  There was a 2016 Ghostbusters movie?
# 69487  When is the trailer for the new Ghostbusters movie coming out cus this sure ain&#39;t a real Ghostbusters movie.
# 70235  Wow, this trailer was just... blah. Nothing special at all. Doesn&#39;t make me excited for a new Ghostbusters let alone an all female Ghostbusters movie.
#
#        age   gender      ethnicity  relevance  \
# 3599   mid  female   white          1
# 3652   mid  unknown  unknown        1
# 7464   mid  unknown  white          1
# 12991  mid  male     white          1
# 15507  mid  unknown  unknown        1
# 16407  mid  male     white          1
# 16762  mid  unknown  unknown        1
# 19195  mid  unknown  white          1
# 19489  mid  unknown  unknown        1
# 20656  mid  male     african_black  1
# 21576  mid  male     unknown        1
# 26878  mid  unknown  unknown        1
# 27615  mid  unknown  unknown        1
# 27838  mid  unknown  unknown        1
# 32111  mid  male     white          1
# 33258  mid  unknown  unknown        1
# 44772  mid  female   unknown        1
# 45183  mid  male     white          1
# 48983  mid  unknown  unknown        1
# 51369  mid  unknown  unknown        1
# 51666  mid  male     unknown        1
# 52176  mid  male     hispanic       1
# 52378  mid  unknown  unknown        1
# 56066  mid  female   hispanic       1
# 57977  mid  unknown  unknown        1
# 58197  mid  unknown  unknown        1
# 59367  mid  unknown  unknown        1
# 60951  mid  male     white          1
# 62693  mid  unknown  unknown        1
# 69487  mid  unknown  unknown        1
# 70235  mid  unknown  unknown        1
#
#                                                                                                                   comment_tokens  \
# 3599   [ghostbusters, movies]
# 3652   [real, ghostbusters, movie, fans, original, gotten, f, ghostbusters, movie]
# 7464   [course, ghostbusters, movie]
# 12991  [ghostbusters, ghostbusters, ghostbusters, gets, way, much, hate, cool, movie]
# 15507  [shocker, woman, doesnt, replacement, movie, awful, feminine, excuse, ghostbusters, movie]
# 16407  [ghostbusters, movieiam, excited, ghostbusters, movie, real, ghostbuters, movie]
# 16762  [ghostbusters, horror, movie]
# 19195  [movie, destroyed, ghostbusters, franchisingbr, br, yesi, saw, moviea, bad, movie]
# 19489  [sloth, nope, truly, looks, movie, seriously, regular, ghostbusters, movie]
# 20656  [reboot, ghostbusters, next, year, ghostbusters, played, deadpoolbr, br, maybe, deadpool, play, roles, movies]
# 21576  [ghostbusters, hillary, clinton, movies]
# 26878  [ghostbusters, movie]
# 27615  [sad, excuse, ghostbusters, movie]
# 27838  [imo, ok, funny, movie, terrible, ghostbusters, movie]
# 32111  [ghostbusters, trash, movie]
# 33258  [honestly, ghostbusters, movie]
# 44772  [fail, see, feminist, ghostbusters, simply, terrible, movie]
# 45183  [extreme, ghostbusters, movie]
# 48983  [complete, utter, garbagebr, chose, make, piece, shit, extreme, ghostbusters, movie]
# 51369  [ghostbusters, million, dollars, disaster, horrible, movie]
# 51666  [ghostbusters, never, ghostbusters, cartoon, better, story, movie]
# 52176  [ghostbusters, movie, included, amy, pohler, tina, fey, definitely, billion, dollar, movie]
# 52378  [cool, adam, sandler, making, ghostbusters, movie]
# 56066  [holygrail, right, fanbase, forgot, dude, kidsfamily, movie, cant, expect, shakespeare, ghostbusters, movie]
# 57977  [new, ghostbusters, movie, way, better, boring, old, ghostbusters, movie]
# 58197  [fucked, ghostbusters, movie]
# 59367  [ghostbusters, horror, movie]
# 60951  [looking, forward, seeing, ghostbusters, afterlife, movie]
# 62693  [ghostbusters, movie]
# 69487  [trailer, new, ghostbusters, movie, coming, cus, sure, aint, real, ghostbusters, movie]
# 70235  [wow, trailer, blah, nothing, special, doesnt, make, excited, new, ghostbusters, let, alone, female, ghostbusters, movie]
#
#        related_tag  sim_score sentiment_score  age_score  gender_score  \
# 3599   1.25         0.789207   negative        0.777181   1.000000
# 3652   1.25         0.955170   negative        0.500000   1.000000
# 7464   1.25         0.789207   negative        0.500000   1.000000
# 12991  1.25         0.962303   negative        0.675446   1.000000
# 15507  1.25         0.998942   negative        0.500000   1.000000
# 16407  1.25         0.928597   negative        0.500000   1.000000
# 16762  1.25         0.789207   negative        0.500000   1.000000
# 19195  1.25         0.998282   negative        0.500000   1.000000
# 19489  1.25         0.996960   negative        0.500000   1.000000
# 20656  1.25         0.987591   positive        0.500000   0.929263
# 21576  1.25         0.789207   negative        0.701198   1.000000
# 26878  1.25         0.789207   negative        0.500000   1.000000
# 27615  1.25         0.789207   negative        0.500000   1.000000
# 27838  1.25         0.996960   negative        0.500000   1.000000
# 32111  1.25         0.789207   negative        0.683487   1.000000
# 33258  1.25         0.789207   positive        0.500000   1.000000
# 44772  1.25         0.991264   negative        0.599602   1.000000
# 45183  1.25         0.789207   negative        0.699719   1.000000
# 48983  1.25         0.996139   negative        0.500000   1.000000
# 51369  1.25         0.789207   negative        0.500000   1.000000
# 51666  1.25         0.971305   negative        0.623831   1.000000
# 52176  1.25         0.980288   negative        0.595151   1.000000
# 52378  1.25         0.999376   negative        0.500000   1.000000
# 56066  1.25         0.999602   negative        0.543165   0.792931
# 57977  1.25         0.919730   negative        0.500000   1.000000
# 58197  1.25         0.789207   negative        0.500000   1.000000
# 59367  1.25         0.789207   negative        0.500000   1.000000
# 60951  1.50         0.811795   negative        0.741288   1.000000
# 62693  1.25         0.789207   negative        0.500000   1.000000
# 69487  1.50         0.933819   negative        0.500000   1.000000
# 70235  1.50         0.925328   negative        0.500000   1.000000
#
#        ethnicity_score  com_cluster
# 3599   1.000000         4
# 3652   1.000000         4
# 7464   1.000000         4
# 12991  0.736274         4
# 15507  1.000000         4
# 16407  1.000000         4
# 16762  1.000000         4
# 19195  1.000000         4
# 19489  1.000000         4
# 20656  0.982551         4
# 21576  1.000000         4
# 26878  1.000000         4
# 27615  1.000000         4
# 27838  1.000000         4
# 32111  1.000000         4
# 33258  1.000000         4
# 44772  1.000000         4
# 45183  1.000000         4
# 48983  1.000000         4
# 51369  1.000000         4
# 51666  1.000000         4
# 52176  1.000000         4
# 52378  1.000000         4
# 56066  1.000000         4
# 57977  1.000000         4
# 58197  1.000000         4
# 59367  1.000000         4
# 60951  1.000000         4
# 62693  1.000000         4
# 69487  1.000000         4
# 70235  1.000000         4

# %%
ghostbuster_comment[ghostbuster_comment['com_id'] == '5e6334ff-9f9f-4570-9e91-90f973ef0a82']['com']
# Out:
# 15507    What a shocker: a woman doesn’t like the replacement movie to an awful feminine excuse for a ghostbusters movie
# Name: com, dtype: object

# %%
ghostbuster_comment[ghostbuster_comment['com_id'] == '5e7127f0-1221-46c4-a1e2-ff757113c7e5']['com']
# Out:
# 70235    Wow, this trailer was just... blah. Nothing special at all. Doesn&#39;t make me excited for a new Ghostbusters let alone an all female Ghostbusters movie.
# Name: com, dtype: object

# %% [markdown]
# # 6. Passionate Comment/Audience Classification

# %% [markdown]
# ## 6.1 Loading Dataset and Cleaning Numeric Columns

# %%
# Loading Data
relevant_comment_initial = pd.read_csv('relevant_comment.csv')

# %%
relevant_comment_initial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72447 entries, 0 to 72446
# Data columns (total 8 columns):
# Unnamed: 0    72447 non-null int64
# com_id        72447 non-null object
# vid_id        72447 non-null object
# com           72446 non-null object
# age           72447 non-null object
# gender        72447 non-null object
# ethnicity     72447 non-null object
# relevance     72447 non-null int64
# dtypes: int64(2), object(6)
# memory usage: 4.4+ MB

# %%
# Getting demographic features and cleaning people with < 0.5 probability score
demog = ['age','gender','ethnicity']
for i in demog:
    score_col_name = '{}_score'.format(i)
    relevant_comment_initial[score_col_name] = relevant_comment_initial[i].apply(lambda x: ast.literal_eval(x)['score'])
    relevant_comment_initial[i] = relevant_comment_initial[i].apply(lambda x: ast.literal_eval(x)['value'])

# %%
relevant_comment_initial = relevant_comment_initial[relevant_comment_initial['age_score'] >= 0.5][relevant_comment_initial['gender_score'] >= 0.5][relevant_comment_initial['ethnicity_score'] >= 0.5]

# %%
# Getting popularity features from the descriptions_final dataframe. Popularity features = numbers of comments, likes, and dislikes
descriptions_final = pd.read_csv('descriptions_final')
relevant_comment_initial = pd.merge(relevant_comment_initial, descriptions_final[['vid_id','com_num','like_num','dis_num']],on='vid_id',how='left')

# %%
# Cleaning and removing wrong records on popularity features
float_col = ['com_num','like_num','dis_num']
for col in float_col:
    relevant_comment_initial[col] = relevant_comment_initial[col].astype(np.int64)
    
relevant_comment_initial = relevant_comment_initial[relevant_comment_initial['com_num'] >= 0][relevant_comment_initial['like_num'] >= 0][relevant_comment_initial['dis_num'] >= 0]

# %% [markdown]
# ## 6.1 Checking for Class Imbalance and EDA

# %%
# Expectedly, very serious class imbalance
relevant_comment_initial['passionate_audience'] = relevant_comment_initial.loc[:,'com_id'].apply(lambda x: 1 if x in list(ghostbuster_comment.com_id) else 0)
relevant_comment_initial.groupby('passionate_audience').count()
# Out:
#                      Unnamed: 0  com_id  vid_id    com    age  gender  \
# passionate_audience
# 0                    71470       71470   71470   71469  71470  71470
# 1                    826         826     826     826    826    826
#
#                      ethnicity  relevance  age_score  gender_score  \
# passionate_audience
# 0                    71470      71470      71470      71470
# 1                    826        826        826        826
#
#                      ethnicity_score  com_num  like_num  dis_num
# passionate_audience
# 0                    71470            71470    71470     71470
# 1                    826              826      826       826

# %%
# factorplot for passionate audience and age
fg = sns.catplot(x='age', 
                 y='com_id',
                 col='passionate_audience', 
                 data=relevant_comment_initial.groupby(['passionate_audience','age']).nunique().drop(['age','passionate_audience'],axis=1).reset_index(), 
                 kind='bar',
                 palette='summer_r')

# %%
# factorplot for passionate audience and gender
fg = sns.catplot(x='gender', 
                 y='com_id',
                 col='passionate_audience', 
                 data=relevant_comment_initial.groupby(['passionate_audience','gender']).nunique().drop(['gender','passionate_audience'],axis=1).reset_index(), 
                 kind='bar',
                 palette='summer_r')

# %%
# factorplot for passionate audience and ethnicity
fg = sns.catplot(x='ethnicity', 
                 y='com_id',
                 col='passionate_audience', 
                 data=relevant_comment_initial.groupby(['passionate_audience','ethnicity']).nunique().drop(['ethnicity','passionate_audience'],axis=1).reset_index(), 
                 kind='bar',
                 palette='cubehelix_r')

# %%
# factorplot for passionate audience and popularity features
fg = sns.catplot(x='numeric_fea', 
                 y='mean',
                 col='passionate_audience', 
                 data=relevant_comment_initial.groupby(['passionate_audience']).mean().reset_index()[['passionate_audience','com_num','like_num','dis_num']].melt(id_vars='passionate_audience',
                                                                                                                                            var_name='numeric_fea',
                                                                                                                                            value_name='mean'), 
                 kind='bar',
                 palette='cubehelix_r')

# %% [markdown]
# ## 6.2 Preparing Dataframe for Classification Model Training

# %%
# label encoding categorical features
le = LabelEncoder()
relevant_comment_initial['age'] = le.fit_transform(relevant_comment_initial['age'])
relevant_comment_initial['gender'] = le.fit_transform(relevant_comment_initial['gender'])
relevant_comment_initial['ethnicity'] = le.fit_transform(relevant_comment_initial['ethnicity'])

# %%
# spliting X and y
X = relevant_comment_initial[['age','gender','ethnicity','com_num','like_num','dis_num']]
y = relevant_comment_initial[['passionate_audience']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=43)

# %% [markdown]
# ## 6.3 Training and Tuning Decision Tree Model

# %%
# Building and Tuning a simple tree to double check the prediction. Pre-pruning the tree by limiting max_depth 
# to avoid overfitting
# Increasing the class weight of passionate audience to help with class imbalance:
for i in range(50,56):
    dt = DecisionTreeClassifier(max_depth = 5, class_weight = {0:1,1:i})
    dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    skplt.metrics.plot_confusion_matrix(y_test, y_pred, normalize=True)

# %%
tree.export_graphviz(dt, out_file='trees.dot', max_depth = 5, feature_names = X.columns)

# %%
# Visualizing the tree
Image(filename='tree.png', width = 900, height = 400)
